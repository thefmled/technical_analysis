# %%
los = ['AARTIIND.NS','ACC.NS','ADANIENT.NS','ADANIPORTS.NS','ALKEM.NS','AMARAJABAT.NS','AMBUJACEM.NS','APLLTD.NS','APOLLOHOSP.NS',
      'APOLLOTYRE.NS','ASHOKLEY.NS','ASIANPAINT.NS','AUBANK.NS','AUROPHARMA.NS','AXISBANK.NS','BAJAJFINSV.NS','BAJAJ-AUTO.NS',
      'BAJFINANCE.NS','BALKRISIND.NS','BANDHANBNK.NS','BANKBARODA.NS','^NSEBANK','BATAINDIA.NS','BEL.NS','BERGEPAINT.NS',
      'BHARATFORG.NS','BHARTIARTL.NS','BHEL.NS','BIOCON.NS','BOSCHLTD.NS','BPCL.NS','BRITANNIA.NS','CADILAHC.NS','CANBK.NS',
      'CHOLAFIN.NS','CIPLA.NS','COALINDIA.NS','COFORGE.NS','COLPAL.NS','CONCOR.NS','CUB.NS','CUMMINSIND.NS','DABUR.NS','DEEPAKNTR.NS',
      'DIVISLAB.NS','DLF.NS','DRREDDY.NS','EICHERMOT.NS','ESCORTS.NS','EXIDEIND.NS','FEDERALBNK.NS','GAIL.NS','GLENMARK.NS',
      'GMRINFRA.NS','GODREJCP.NS','GODREJPROP.NS','GRANULES.NS','GRASIM.NS','HAVELLS.NS','HCLTECH.NS','HDFC.NS','HDFCBANK.NS',
      'HDFCLIFE.NS','HEROMOTOCO.NS','HINDALCO.NS','HINDPETRO.NS','HINDUNILVR.NS','IBULHSGFIN.NS','ICICIBANK.NS','ICICIGI.NS',
      'ICICIPRULI.NS','IDEA.NS','IDFCFIRSTB.NS','IGL.NS','INDIGO.NS','INDUSINDBK.NS','INFY.NS','IOC.NS','IRCTC.NS','ITC.NS',
      'JINDALSTEL.NS','JSWSTEEL.NS','JUBLFOOD.NS','KOTAKBANK.NS','LICHSGFIN.NS','LT.NS','LTI.NS','LTTS.NS','LUPIN.NS','MANAPPURAM.NS',
      'MARICO.NS','MARUTI.NS','MCDOWELL-N.NS','MGL.NS','MINDTREE.NS','MOTHERSUMI.NS','MPHASIS.NS','MRF.NS','MUTHOOTFIN.NS',
      'M&M.NS','M&MFIN.NS','NATIONALUM.NS','NAUKRI.NS','NAVINFLUOR.NS','NCC.NS','NESTLEIND.NS','^NSEI','NMDC.NS','NTPC.NS',
      'ONGC.NS','PAGEIND.NS','PEL.NS','PETRONET.NS','PFIZER.NS','PIDILITIND.NS','PIIND.NS','PNB.NS','POWERGRID.NS','PVR.NS',
      'RAMCOCEM.NS','RBLBANK.NS','RECLTD.NS','RELIANCE.NS','SAIL.NS','SBILIFE.NS','SBIN.NS','SHREECEM.NS','SIEMENS.NS','SRF.NS',
      'SRTRANSFIN.NS','SUNPHARMA.NS','SUNTV.NS','TATACHEM.NS','TATACONSUM.NS','TATAMOTORS.NS','TATAPOWER.NS','TATASTEEL.NS',
      'TCS.NS','TECHM.NS','TITAN.NS','TORNTPHARM.NS','TORNTPOWER.NS','TRENT.NS','TVSMOTOR.NS','UBL.NS','ULTRACEMCO.NS',
      'UPL.NS','VEDL.NS','VOLTAS.NS','WIPRO.NS','ZEEL.NS']

# %%
import pandas as pd
import numpy as np
import yfinance
import mplfinance as mpf
import pandas as pd
import warnings
warnings.simplefilter("ignore")
from stockstats import StockDataFrame
import datetime


#PREDEFINED FUNCTIONS
def date_presence(li, x):
    for date in li:
        if date==x:
            return True
    return False

def filter_divs(divergences, start, end):
    start = datetime.datetime.strptime(start, '%Y-%m-%d')
    end = datetime.datetime.strptime(end, '%Y-%m-%d')
    for i in divergences.index:
        if divergences['Date'][i] <= start or divergences['Date'][i] >= end:
            divergences.drop(i, axis = 0, inplace = True)
    i = [x for x in range(len(divergences.index))]
    divergences.index = i
    return divergences

#CANDLESTICK FORMATION CODE
import talib
from talib import MA_Type
candle_names = talib.get_function_groups()['Pattern Recognition']

candle_rankings = {
        "CDL3LINESTRIKE_Bull": 1,
        "CDL3LINESTRIKE_Bear": 2,
        "CDL3BLACKCROWS_Bull": 3,
        "CDL3BLACKCROWS_Bear": 3,
        "CDLEVENINGSTAR_Bull": 4,
        "CDLEVENINGSTAR_Bear": 4,
        "CDLTASUKIGAP_Bull": 5,
        "CDLTASUKIGAP_Bear": 5,
        "CDLINVERTEDHAMMER_Bull": 6,
        "CDLINVERTEDHAMMER_Bear": 6,
        "CDLMATCHINGLOW_Bull": 7,
        "CDLMATCHINGLOW_Bear": 7,
        "CDLABANDONEDBABY_Bull": 8,
        "CDLABANDONEDBABY_Bear": 8,
        "CDLBREAKAWAY_Bull": 10,
        "CDLBREAKAWAY_Bear": 10,
        "CDLMORNINGSTAR_Bull": 12,
        "CDLMORNINGSTAR_Bear": 12,
        "CDLPIERCING_Bull": 13,
        "CDLPIERCING_Bear": 13,
        "CDLSTICKSANDWICH_Bull": 14,
        "CDLSTICKSANDWICH_Bear": 14,
        "CDLTHRUSTING_Bull": 15,
        "CDLTHRUSTING_Bear": 15,
        "CDLINNECK_Bull": 17,
        "CDLINNECK_Bear": 17,
        "CDL3INSIDE_Bull": 20,
        "CDL3INSIDE_Bear": 56,
        "CDLHOMINGPIGEON_Bull": 21,
        "CDLHOMINGPIGEON_Bear": 21,
        "CDLDARKCLOUDCOVER_Bull": 22,
        "CDLDARKCLOUDCOVER_Bear": 22,
        "CDLIDENTICAL3CROWS_Bull": 24,
        "CDLIDENTICAL3CROWS_Bear": 24,
        "CDLMORNINGDOJISTAR_Bull": 25,
        "CDLMORNINGDOJISTAR_Bear": 25,
        "CDLXSIDEGAP3METHODS_Bull": 27,
        "CDLXSIDEGAP3METHODS_Bear": 26,
        "CDLTRISTAR_Bull": 28,
        "CDLTRISTAR_Bear": 76,
        "CDLGAPSIDESIDEWHITE_Bull": 46,
        "CDLGAPSIDESIDEWHITE_Bear": 29,
        "CDLEVENINGDOJISTAR_Bull": 30,
        "CDLEVENINGDOJISTAR_Bear": 30,
        "CDL3WHITESOLDIERS_Bull": 32,
        "CDL3WHITESOLDIERS_Bear": 32,
        "CDLONNECK_Bull": 33,
        "CDLONNECK_Bear": 33,
        "CDL3OUTSIDE_Bull": 34,
        "CDL3OUTSIDE_Bear": 39,
        "CDLRICKSHAWMAN_Bull": 35,
        "CDLRICKSHAWMAN_Bear": 35,
        "CDLSEPARATINGLINES_Bull": 36,
        "CDLSEPARATINGLINES_Bear": 40,
        "CDLLONGLEGGEDDOJI_Bull": 37,
        "CDLLONGLEGGEDDOJI_Bear": 37,
        "CDLHARAMI_Bull": 38,
        "CDLHARAMI_Bear": 72,
        "CDLLADDERBOTTOM_Bull": 41,
        "CDLLADDERBOTTOM_Bear": 41,
        "CDLCLOSINGMARUBOZU_Bull": 70,
        "CDLCLOSINGMARUBOZU_Bear": 43,
        "CDLTAKURI_Bull": 47,
        "CDLTAKURI_Bear": 47,
        "CDLDOJISTAR_Bull": 49,
        "CDLDOJISTAR_Bear": 51,
        "CDLHARAMICROSS_Bull": 50,
        "CDLHARAMICROSS_Bear": 80,
        "CDLADVANCEBLOCK_Bull": 54,
        "CDLADVANCEBLOCK_Bear": 54,
        "CDLSHOOTINGSTAR_Bull": 55,
        "CDLSHOOTINGSTAR_Bear": 55,
        "CDLMARUBOZU_Bull": 71,
        "CDLMARUBOZU_Bear": 57,
        "CDLUNIQUE3RIVER_Bull": 60,
        "CDLUNIQUE3RIVER_Bear": 60,
        "CDL2CROWS_Bull": 61,
        "CDL2CROWS_Bear": 61,
        "CDLBELTHOLD_Bull": 62,
        "CDLBELTHOLD_Bear": 63,
        "CDLHAMMER_Bull": 65,
        "CDLHAMMER_Bear": 65,
        "CDLHIGHWAVE_Bull": 67,
        "CDLHIGHWAVE_Bear": 67,
        "CDLSPINNINGTOP_Bull": 69,
        "CDLSPINNINGTOP_Bear": 73,
        "CDLUPSIDEGAP2CROWS_Bull": 74,
        "CDLUPSIDEGAP2CROWS_Bear": 74,
        "CDLGRAVESTONEDOJI_Bull": 77,
        "CDLGRAVESTONEDOJI_Bear": 77,
        "CDLHIKKAKEMOD_Bull": 82,
        "CDLHIKKAKEMOD_Bear": 81,
        "CDLHIKKAKE_Bull": 85,
        "CDLHIKKAKE_Bear": 83,
        "CDLENGULFING_Bull": 84,
        "CDLENGULFING_Bear": 91,
        "CDLMATHOLD_Bull": 86,
        "CDLMATHOLD_Bear": 86,
        "CDLHANGINGMAN_Bull": 87,
        "CDLHANGINGMAN_Bear": 87,
        "CDLRISEFALL3METHODS_Bull": 94,
        "CDLRISEFALL3METHODS_Bear": 89,
        "CDLKICKING_Bull": 96,
        "CDLKICKING_Bear": 102,
        "CDLDRAGONFLYDOJI_Bull": 98,
        "CDLDRAGONFLYDOJI_Bear": 98,
        "CDLCONCEALBABYSWALL_Bull": 101,
        "CDLCONCEALBABYSWALL_Bear": 101,
        "CDL3STARSINSOUTH_Bull": 103,
        "CDL3STARSINSOUTH_Bear": 103,
        "CDLDOJI_Bull": 104,
        "CDLDOJI_Bear": 104,
        "CDLLONGLINE_Bull": 53,
        "CDLLONGLINE_Bear": 53,
        "CDLSHORTLINE_Bull": 85,
        "CDLSHORTLINE_Bear": 66,
        "CDLSTALLEDPATTERN_Bull": 93,
        "CDLSTALLEDPATTERN_Bear": 93,
        "CDLKICKINGBYLENGTH": 96,
        "CDLKICKINGBYLENGTH_Bear": 102,
        'CDLCOUNTERATTACK_Bull': 103,
        'CDLCOUNTERATTACK_Bear': 103
}

from itertools import compress
import operator

def candlesticks(df):
    op = df['Open']
    hi = df['High']
    lo = df['Low']
    cl = df['Close']
    # create columns for each pattern
    for candle in candle_names:
    # below is same as;
    # df["CDL3LINESTRIKE"] = talib.CDL3LINESTRIKE(op, hi, lo, cl)
        df[candle] = getattr(talib, candle)(op, hi, lo, cl)
    df['candlestick_pattern'] = np.nan
    df['candlestick_match_count'] = np.nan
    for index, row in df.iterrows():
            # no pattern found
        if len(row[candle_names]) - sum(row[candle_names] == 0) == 0:
            df.loc[index,'candlestick_pattern'] = ""
            df.loc[index, 'candlestick_match_count'] = 0
            # single pattern found
        elif len(row[candle_names]) - sum(row[candle_names] == 0) == 1:
                # bull pattern 100 or 200
            if any(row[candle_names].values > 0):
                pattern = list(compress(row[candle_names].keys(), row[candle_names].values != 0))[0] + '_Bull'
                df.loc[index, 'candlestick_pattern'] = pattern
                df.loc[index, 'candlestick_match_count'] = 1
                # bear pattern -100 or -200
            else:
                pattern = list(compress(row[candle_names].keys(), row[candle_names].values != 0))[0] + '_Bear'
                df.loc[index, 'candlestick_pattern'] = pattern
                df.loc[index, 'candlestick_match_count'] = 1
            # multiple patterns matched -- select best performance
        else:
            # filter out pattern names from bool list of values
            patterns = list(compress(row[candle_names].keys(), row[candle_names].values != 0))
            container = []
            for pattern in patterns:
                if row[pattern] > 0:
                    container.append(pattern + '_Bull')
                else:
                    container.append(pattern + '_Bear')
            rank_list = [candle_rankings[p] for p in container]
            if len(rank_list) == len(container):
                rank_index_best = rank_list.index(min(rank_list))
                df.loc[index, 'candlestick_pattern'] = container[rank_index_best]
                df.loc[index, 'candlestick_match_count'] = len(container)
        # clean up candle columns
    df.drop(candle_names, axis = 1, inplace = True)
    return df

def minute_eq(hour):
    if hour==1:
        minute=1
    else:
        minute = 4*(hour-1)
    return minute

def hour_eq(minute):
    hour = (minute)//4 + 1
    return hour

def gap_analysis(df):
    df['Gaps']=''
    for i in range(1, len(df.index)):
        if df['Low'][i] > df['High'][i-1]:
            df['Gaps'][i] = 'GAP UP'
        elif df['High'][i] < df['Low'][i-1]:
            df['Gaps'][i] = 'GAP DOWN'
    return df

# %%
#MAIN FUNCTION TO ITERATE OVER ALL STOCKS IN LIST
def trades(name, w_ct, w_re, w_dd, w_dg, w_hg):
    ticker = yfinance.Ticker(name)
    df = ticker.history(interval="1d",start="2019-06-01", end="2021-05-26")
    df['Date'] = pd.to_datetime(df.index)
    df = df.loc[:,['Date', 'Open', 'High', 'Low', 'Close']]
    #rounding off to three decimal places
    df['Open'] = round(df['Open'], 3)
    df['High'] = round(df['High'], 3)
    df['Low'] = round(df['Low'], 3)
    df['Close'] = round(df['Close'], 3)
    h_df = ticker.history(interval="1h",start="2019-06-01", end="2021-05-26")
    h_df['Date'] = pd.to_datetime(h_df.index)
    h_df = h_df.loc[:,['Date', 'Open', 'High', 'Low', 'Close']]
    h_df['Open'] = round(h_df['Open'], 3)
    h_df['High'] = round(h_df['High'], 3)
    h_df['Low'] = round(h_df['Low'], 3)
    h_df['Close'] = round(h_df['Close'], 3)
    hour = []
    j=0
    c=0
    for i in range(len(h_df['Date'])):
        date = h_df['Date'][j]
        if h_df['Date'][i]==date:
            hour.append(c+1)
            c+=1
        else:
            hour.append(1)
            c=1
            j=i
    h_df['Hour']=hour
    
    
    # daily macd
    exp11_d = df['Close'].ewm(span=12, adjust=False).mean()
    exp22_d = df['Close'].ewm(span=26, adjust=False).mean()
    macd = exp11_d - exp22_d
    signal = macd.ewm(span=9, adjust = False).mean()
    exp50_d = df['Close'].ewm(span=50, adjust=False).mean()
    df['macd_hist'] = macd - signal
    df['exp11'] = exp11_d
    df['exp22'] = exp22_d
    df['exp50'] = exp50_d

    
    #daily rsi
    stock_d = StockDataFrame.retype(df.copy())
    df['RSI'] = stock_d['rsi_14']

    #DIVERGENCE IDENTIFICATION ON DAILY
    d_tol_m = 0.001*np.mean(df['macd_hist'])
    d_tol_p = 0.001*np.mean(df['Close'])
    n=2
    crest_d = []
    trough_d = []
    for i in range(1, len(df['Date'])-1):
        if df['macd_hist'][i]>df['macd_hist'][i-1] and df['macd_hist'][i]>df['macd_hist'][i+1] and df['macd_hist'][i]>0:
            crest_d.append([i, df['Date'][i], df['macd_hist'][i], df['High'][i], df['RSI'][i]])
        elif df['macd_hist'][i]<df['macd_hist'][i-1] and df['macd_hist'][i]<df['macd_hist'][i+1] and df['macd_hist'][i]<0:
            trough_d.append([i, df['Date'][i], df['macd_hist'][i], df['Low'][i], df['RSI'][i]])
    crest_d = pd.DataFrame(crest_d, columns = ['Index','Date', 'macd', 'High', 'RSI'])
    trough_d = pd.DataFrame(trough_d, columns = ['Index','Date', 'macd', 'Low', 'RSI'])
      
    temp_bear_d = []
    for i in crest_d.index[1:]:
        if crest_d['macd'][i]<(crest_d['macd'][i-1]-d_tol_m) and crest_d['High'][i]>(crest_d['High'][i-1]+d_tol_p) and crest_d['RSI'][i]<70 and (crest_d['Index'][i] - crest_d['Index'][i-1])>n:
            temp_bear_d.append([crest_d['Index'][i], crest_d['Date'][i]])
    bear_d = pd.DataFrame(temp_bear_d, columns = ['Index','Date'])
    
    temp_bull_d = []
    for i in trough_d.index[1:]:
        if trough_d['macd'][i]>(trough_d['macd'][i-1]+d_tol_m) and trough_d['Low'][i]<(trough_d['Low'][i-1]-d_tol_p) and trough_d['RSI'][i]>30 and (trough_d['Index'][i] - trough_d['Index'][i-1])>n:
            temp_bull_d.append([trough_d['Index'][i], trough_d['Date'][i]])
    bull_d = pd.DataFrame(temp_bull_d, columns = ['Index', 'Date'])

    
    # hourly macd
    exp11_h = h_df['Close'].ewm(span=12, adjust=False).mean()
    exp22_h = h_df['Close'].ewm(span=26, adjust=False).mean()
    macd_h = exp11_h - exp22_h
    signal_h = macd_h.ewm(span=9, adjust = False).mean()
    h_df['macd_hist'] = macd_h - signal_h
    h_df['exp11'] = exp11_h
    h_df['exp22'] = exp22_h
    exp50_h = h_df['Close'].ewm(span=50, adjust=False).mean()
    h_df['exp50'] = exp50_h

    
    #BOLLINGER BANDS ON HOURLY DF
    h_df['bb_upper'], h_df['bb_middle'], h_df['bb_lower'] = talib.BBANDS(h_df['Close'], matype=MA_Type.T3)
    
    
    #hourly rsi
    stock_h = StockDataFrame.retype(h_df.copy())
    h_df['RSI'] = stock_h['rsi_14']

    
    #DIVERGENCE IDENTIFICATION ON HOURLY
    h_tol_m = 0.001*np.mean(h_df['macd_hist'])
    h_tol_p = 0.001*np.mean(h_df['Close'])
    crest_h = []
    trough_h = []
    for i in range(1, len(h_df['Date'])-1):
        if h_df['macd_hist'][i]>h_df['macd_hist'][i-1] and h_df['macd_hist'][i]>h_df['macd_hist'][i+1] and h_df['macd_hist'][i]>0:
            crest_h.append([i, h_df['Date'][i], h_df['Hour'][i], h_df['macd_hist'][i], h_df['High'][i], h_df['RSI'][i]])
        elif h_df['macd_hist'][i]<h_df['macd_hist'][i-1] and h_df['macd_hist'][i]<h_df['macd_hist'][i+1] and h_df['macd_hist'][i]<0:
            trough_h.append([i, h_df['Date'][i], h_df['Hour'][i], h_df['macd_hist'][i], h_df['Low'][i], h_df['RSI'][i]])
    crest_h = pd.DataFrame(crest_h, columns = ['Index', 'Date', 'Hour', 'macd', 'High', 'RSI'])
    trough_h = pd.DataFrame(trough_h, columns = ['Index', 'Date', 'Hour', 'macd', 'Low', 'RSI'])

    temp_bear_h = []
    for i in crest_h.index[1:]:
        if crest_h['macd'][i]<(crest_h['macd'][i-1]-h_tol_m) and crest_h['High'][i]>(crest_h['High'][i-1]+h_tol_p) and crest_h['RSI'][i]<70 and (crest_h['Index'][i] - crest_h['Index'][i-1])>n:
            temp_bear_h.append([crest_h['Index'][i], crest_h['Date'][i], crest_h['Hour'][i]])
    bear_h = pd.DataFrame(temp_bear_h, columns = ['Index', 'Date', 'Hour'])

    temp_bull_h = []
    for i in trough_h.index[1:]:
        if trough_h['macd'][i]>(trough_h['macd'][i-1]+h_tol_m) and trough_h['Low'][i]<(trough_h['Low'][i-1]-h_tol_p) and trough_h['RSI'][i]>30 and (trough_h['Index'][i] - trough_h['Index'][i-1])>n:
            temp_bull_h.append([trough_h['Index'][i], trough_h['Date'][i], trough_h['Hour'][i]])
    bull_h = pd.DataFrame(temp_bull_h, columns = ['Index', 'Date', 'Hour'])
    
    
    #GAPS ON H_DF AND DF
    h_df = gap_analysis(h_df)
    df = gap_analysis(df)
    
    
    #FOLLOW THROUGH OF DAILY DIVERGENCES (D3) 
    ft_bear_d = []
    ft_bear_h = []
    ft_bull_d = []
    ft_bull_h = []
    
    for i in bear_d.index:
        div_index = bear_d['Index'][i]
        for j in range(div_index+1, min(div_index+4, len(df['Date']))):
            if df['Low'][j] < df['Low'][div_index]:
                ft_bear_d.append([j, df['Date'][j]])
                break

    for i in bull_d.index:
        div_index = bull_d['Index'][i]
        for j in range(div_index+1, min(div_index+4, len(df['Date']))):
            if df['High'][j] > df['High'][div_index]:
                ft_bull_d.append([j, df['Date'][j]])
                break
                
    ft_bear_d = pd.DataFrame(ft_bear_d, columns = ['Index','Date'])
    ft_bull_d = pd.DataFrame(ft_bull_d, columns = ['Index', 'Date'])

    #FOLLOW THROUGH OF HOURLY DIVERGENCES
    for i in bull_h.index:
        div_index = bull_h['Index'][i]
        for j in range(div_index+1, min(div_index+22, len(h_df['Date']))):
            if h_df['High'][j] > h_df['High'][div_index]:
                ft_bull_h.append([j, h_df['Date'][j], h_df['Hour'][j]])
                break

    for i in bear_h.index:
        div_index = bear_h['Index'][i]
        for j in range(div_index+1, min(div_index+22, len(h_df['Date']))):
            if h_df['Low'][j] < h_df['Low'][div_index]:
                ft_bear_h.append([j, h_df['Date'][j], h_df['Hour'][j]])
                break
                
    ft_bear_h = pd.DataFrame(ft_bear_h, columns = ['Index','Date','Hour'])
    ft_bull_h = pd.DataFrame(ft_bull_h, columns = ['Index','Date','Hour'])
    
    
    #LOADING THE 15 MINUTE CHART
    min_df = yfinance.download(name, period = '60d', interval = '15m')
    min_df = pd.DataFrame(min_df)
    min_df['Date'] = pd.to_datetime(min_df.index)
    min_df = min_df.loc[:,['Date', 'Open', 'High', 'Low', 'Close']]
    dates = []
    for j in range(len(min_df['Date'])):
        dates.append(str(min_df['Date'][j])[:10])
    min_df['Date'] = pd.to_datetime(dates)

    minute = []
    j=0
    c=0
    for i in range(len(min_df['Date'])):
        date = min_df['Date'][j]
        if min_df['Date'][i]==date:
            minute.append(c+1)
            c+=1
        else:
            minute.append(1)
            c=1
            j=i
    min_df['Minute']=minute
    min_df['Open'] = round(min_df['Open'], 3)
    min_df['High'] = round(min_df['High'], 3)
    min_df['Low'] = round(min_df['Low'], 3)
    min_df['Close'] = round(min_df['Close'], 3)
    
    
    #APPENDING CANDLESTICK FORMATIONS TO DF
    df = candlesticks(df)
    
    
    #GENERATING BUY SIGNALS ON 15 MIN CHART (ENTRY)
    buy_date_entry = []
    buy_minute_entry = []
    buy_ohlc_entry = []
    d1_date = []
    d1_minute = []
    d1_ohlc = []
    buy_cond = []

    for date in min_df['Date'].unique():
        day_i = int(np.where(df['Date']==date)[0])
        gap_hour_i = np.where((h_df['Date']==date)&(h_df['Gaps']=='GAP UP'))[0]
        if date_presence(bull_h['Date'], date) and date_presence(bull_d['Date'], date):
            z = np.where(bull_h['Date']==date)[0]
            for hour_i in z:
                minute = minute_eq(bull_h['Hour'][hour_i])
                j = int(np.where((min_df['Date'] == date) & (min_df['Minute'] == minute))[0])
                for k in range(j+1, min(j+76, len(min_df['Date']))):
                    if (min_df['High'][k] > min_df['High'][j]):
                        for c in range(w_ct):
                            buy_date_entry.append(min_df['Date'][k])
                            buy_minute_entry.append(min_df['Minute'][k])
                            buy_ohlc_entry.append((min_df['Open'][k], min_df['High'][k], min_df['Low'][k], min_df['Close'][k]))
                            d1_date.append(date)
                            d1_minute.append(minute)
                            d1_ohlc.append((min_df['Open'][j], min_df['High'][j], min_df['Low'][j], min_df['Close'][j]))
                            buy_cond.append('CONTRA-TREND TRADE')
                        break
        if date_presence(bull_h['Date'], date) and date_presence(bear_d['Date'], date)==False:
            y = np.where(bull_h['Date']==date)[0]
            for hour_i in y:
                minute = minute_eq(bull_h['Hour'][hour_i])
                j = int(np.where((min_df['Date'] == date) & (min_df['Minute'] == minute))[0])
                for k in range(j+1, min(j+76, len(min_df['Date']))):
                    i = int(np.where(df['Date']==min_df['Date'][k])[0])
                    if ((df['High'][i]>=df['exp11'][i] and df['Low'][i]<=df['exp11'][i]) or (df['High'][i]>=df['exp22'][i] and df['Low'][i]<=df['exp22'][i])): 
                        if df['Close'][i] > df['exp50'][i] and df['candlestick_pattern'][i][-4:]=='Bull' and min_df['High'][k] > min_df['High'][j]:
                            for c in range(w_re):
                                buy_date_entry.append(min_df['Date'][k])
                                buy_minute_entry.append(min_df['Minute'][k])
                                buy_ohlc_entry.append((min_df['Open'][k], min_df['High'][k], min_df['Low'][k], min_df['Close'][k]))
                                d1_date.append(date)
                                d1_minute.append(minute)
                                d1_ohlc.append((min_df['Open'][j], min_df['High'][j], min_df['Low'][j], min_df['Close'][j]))
                                buy_cond.append('RE-ENTRY TRADE')
                            break
        if date_presence(ft_bull_d['Date'], date) and date_presence(bear_h, date)==False:
            i = int((np.where(min_df['Date']==date)[0])[-1])
            for k in range(i+1, min(i+76, len(min_df['Date']))):
                if min_df['High'][k] > min_df['High'][i]:
                    for c in range(w_dd):
                        buy_date_entry.append(min_df['Date'][k])
                        buy_minute_entry.append(min_df['Minute'][k])
                        buy_ohlc_entry.append((min_df['Open'][k], min_df['High'][k], min_df['Low'][k], min_df['Close'][k]))
                        d1_date.append(date)
                        d1_minute.append(min_df['Minute'][i])
                        d1_ohlc.append((min_df['Open'][i], min_df['High'][i], min_df['Low'][i], min_df['Close'][i]))
                        buy_cond.append('DAILY DIVERGENCE TRADE')
                    break
        if df['Gaps'][day_i] == 'GAP UP':
            min_i = np.where(min_df['Date']==date)[0][0]
            d1_min_i = np.where(min_df['Date']==min_df['Date'][min_i-1])[0][0]
            for j in range(min_i+1, min(min_i+76, len(min_df.index))):
                if min_df['High'][j] > min_df['High'][min_i]:
                    for c in range(w_dg):
                        buy_date_entry.append(min_df['Date'][j])
                        buy_minute_entry.append(min_df['Minute'][j])
                        buy_ohlc_entry.append((min_df['Open'][j], min_df['High'][j], min_df['Low'][j], min_df['Close'][j]))
                        d1_date.append(min_df['Date'][d1_min_i])
                        d1_minute.append(min_df['Minute'][d1_min_i])
                        d1_ohlc.append((min_df['Open'][d1_min_i], min_df['High'][d1_min_i], min_df['Low'][d1_min_i], min_df['Close'][d1_min_i]))
                        buy_cond.append('DAILY GAP')
                    break    
        if len(gap_hour_i)!=0:
            hour_i = gap_hour_i
            for y in hour_i:
                min_i = int(np.where((min_df['Date']==date)&(min_df['Minute']==minute_eq(h_df['Hour'][y])))[0])
                if h_df['Date'][y-1] in min_df['Date']:
                    d1_min_i = int(np.where((min_df['Date']==h_df['Date'][y-1])&(min_df['Minute']==minute_eq(h_df['Hour'][y-1])))[0])
                    for j in range(min_i+1, min(min_i+76, len(min_df.index))):
                        if min_df['High'][j] > min_df['High'][min_i]:
                            for c in range(w_hg):
                                buy_date_entry.append(min_df['Date'][j])
                                buy_minute_entry.append(min_df['Minute'][j])
                                buy_ohlc_entry.append((min_df['Open'][j], min_df['High'][j], min_df['Low'][j], min_df['Close'][j]))
                                d1_date.append(min_df['Date'][d1_min_i])
                                d1_minute.append(min_df['Minute'][d1_min_i])
                                d1_ohlc.append((min_df['Open'][d1_min_i], min_df['High'][d1_min_i], min_df['Low'][d1_min_i], min_df['Close'][d1_min_i]))
                                buy_cond.append('HOURLY GAP')
                            break

    buy = pd.DataFrame(list(zip(buy_cond, d1_date, d1_minute, d1_ohlc, buy_date_entry, buy_minute_entry, buy_ohlc_entry)),
                       columns = ['Stock: Condition','D1: Date','D1: Minute','D1: OHLC','Entry: Buy Date','Entry: Buy Candle on Minute','Entry: Buy OHLC'])
    
    
    #GENERATING SELL SIGNALS (ENTRY)
    sell_date_entry = []
    sell_minute_entry = []
    sell_ohlc_entry = []
    d1_date = []
    d1_minute = []
    d1_ohlc = []
    sell_cond = []

    for date in min_df['Date'].unique():
        day_i = int(np.where(df['Date']==date)[0])
        gap_hour_i = np.where((h_df['Date']==date)&(h_df['Gaps']=='GAP DOWN'))[0]
        if date_presence(bear_h['Date'], date) and date_presence(bear_d['Date'], date):
            z = np.where(bear_h['Date']==date)[0]
            for hour_i in z:
                minute = minute_eq(bear_h['Hour'][hour_i])
                j = int(np.where((min_df['Date'] == date) & (min_df['Minute'] == minute))[0])
                for k in range(j+1, min(j+76, len(min_df['Date']))):
                    if (min_df['Low'][k] < min_df['Low'][j]):
                        for c in range(w_ct):
                            sell_date_entry.append(min_df['Date'][k])
                            sell_minute_entry.append(min_df['Minute'][k])
                            sell_ohlc_entry.append((min_df['Open'][k], min_df['High'][k], min_df['Low'][k], min_df['Close'][k]))
                            d1_date.append(date)
                            d1_minute.append(minute)
                            d1_ohlc.append((min_df['Open'][j], min_df['High'][j], min_df['Low'][j], min_df['Close'][j]))
                            sell_cond.append('CONTRA-TREND TRADE')
                        break
        if date_presence(bear_h['Date'], date) and date_presence(bull_d['Date'], date)==False:
            y = np.where(bear_h['Date']==date)[0]
            for hour_i in y:
                minute = minute_eq(bear_h['Hour'][hour_i])
                j = int(np.where((min_df['Date'] == date) & (min_df['Minute'] == minute))[0])
                for k in range(j+1, min(j+76, len(min_df['Date']))):
                    i = int(np.where(df['Date']==min_df['Date'][k])[0])
                    if ((df['High'][i]>=df['exp11'][i] and df['Low'][i]<=df['exp11'][i]) or (df['High'][i]>=df['exp22'][i] and df['Low'][i]<=df['exp22'][i])):
                        if df['Close'][i] < df['exp50'][i] and df['candlestick_pattern'][i][-4:]=='Bear' and min_df['Low'][k] < min_df['Low'][j]:
                            for c in range(w_re):
                                buy_date_entry.append(min_df['Date'][k])
                                buy_minute_entry.append(min_df['Minute'][k])
                                buy_ohlc_entry.append((min_df['Open'][k], min_df['High'][k], min_df['Low'][k], min_df['Close'][k]))
                                d1_date.append(date)
                                d1_minute.append(minute)
                                d1_ohlc.append((min_df['Open'][j], min_df['High'][j], min_df['Low'][j], min_df['Close'][j]))
                                buy_cond.append('RE-ENTRY TRADE')
                            break
        if date_presence(ft_bear_d['Date'], date) and date_presence(bull_h, date)==False:
            i = int((np.where(min_df['Date']==date)[0])[-1])
            for k in range(i+1, min(i+76, len(min_df['Date']))):
                if min_df['Low'][k] < min_df['Low'][i]:
                    for c in range(w_dd):
                        sell_date_entry.append(min_df['Date'][k])
                        sell_minute_entry.append(min_df['Minute'][k])
                        sell_ohlc_entry.append((min_df['Open'][k], min_df['High'][k], min_df['Low'][k], min_df['Close'][k]))
                        d1_date.append(date)
                        d1_minute.append(min_df['Minute'][i])
                        d1_ohlc.append((min_df['Open'][i], min_df['High'][i], min_df['Low'][i], min_df['Close'][i]))
                        sell_cond.append('DAILY DIVERGENCE TRADE')
                    break
        if df['Gaps'][day_i] == 'GAP DOWN':
            min_i = np.where(min_df['Date']==date)[0][0]
            d1_min_i = np.where(min_df['Date']==min_df['Date'][min_i-1])[0][0]
            for j in range(min_i+1, min(min_i+76, len(min_df.index))):
                if min_df['Low'][j] < min_df['Low'][min_i]:
                    for c in range(w_dg):
                        buy_date_entry.append(min_df['Date'][j])
                        buy_minute_entry.append(min_df['Minute'][j])
                        buy_ohlc_entry.append((min_df['Open'][j], min_df['High'][j], min_df['Low'][j], min_df['Close'][j]))
                        d1_date.append(min_df['Date'][d1_min_i])
                        d1_minute.append(min_df['Minute'][d1_min_i])
                        d1_ohlc.append((min_df['Open'][d1_min_i], min_df['High'][d1_min_i], min_df['Low'][d1_min_i], min_df['Close'][d1_min_i]))
                        buy_cond.append('DAILY GAP')
                    break    
        if len(gap_hour_i)!=0:
            hour_i = gap_hour_i
            for y in hour_i:
                min_i = int(np.where((min_df['Date']==date)&(min_df['Minute']==minute_eq(h_df['Hour'][y])))[0])
                if h_df['Date'][y-1] in min_df['Date']:
                    d1_min_i = int(np.where((min_df['Date']==h_df['Date'][y-1])&(min_df['Minute']==minute_eq(h_df['Hour'][y-1])))[0])
                    for j in range(min_i+1, min(min_i+76, len(min_df.index))):
                        if min_df['Low'][j] < min_df['Low'][min_i]:
                            for c in range(w_hg):
                                buy_date_entry.append(min_df['Date'][j])
                                buy_minute_entry.append(min_df['Minute'][j])
                                buy_ohlc_entry.append((min_df['Open'][j], min_df['High'][j], min_df['Low'][j], min_df['Close'][j]))
                                d1_date.append(min_df['Date'][d1_min_i])
                                d1_minute.append(min_df['Minute'][d1_min_i])
                                d1_ohlc.append((min_df['Open'][d1_min_i], min_df['High'][d1_min_i], min_df['Low'][d1_min_i], min_df['Close'][d1_min_i]))
                                buy_cond.append('HOURLY GAP')
                            break 
                            
                            
    sell = pd.DataFrame(list(zip(sell_cond, d1_date, d1_minute, d1_ohlc, sell_date_entry, sell_minute_entry, sell_ohlc_entry)), 
                        columns = ['Stock: Condition','D1: Date','D1: Minute','D1: OHLC','Entry: Sell Date','Entry: Sell Candle on Minute','Entry: Sell OHLC'])
    
    
    #GETTING ALL THE TRANSACTIONS IN THE SAME PLACE (DATAFRAME)
    d1_date = []
    d1_minute = []
    d1_ohlc = []
    d2_date = []
    d2_minute = []
    d2_ohlc = []
    bed_or_bud = []
    trade_entry_price = []
    cond = []

    for i in buy.index:
        d1_date.append(buy['D1: Date'][i])
        d1_minute.append(buy['D1: Minute'][i])
        d1_ohlc.append(buy['D1: OHLC'][i])
        (o,h,l,c) = buy['Entry: Buy OHLC'][i]
        d2_date.append(buy['Entry: Buy Date'][i])
        d2_minute.append(buy['Entry: Buy Candle on Minute'][i])
        d2_ohlc.append((o,h,l,c))
        bed_or_bud.append('BuD')
        trade_entry_price.append(l)
        cond.append(buy['Stock: Condition'][i])

    for i in sell.index:
        d1_date.append(sell['D1: Date'][i])
        d1_minute.append(sell['D1: Minute'][i])
        d1_ohlc.append(sell['D1: OHLC'][i])
        (o,h,l,c) = sell['Entry: Sell OHLC'][i]
        d2_date.append(sell['Entry: Sell Date'][i])
        d2_minute.append(sell['Entry: Sell Candle on Minute'][i])
        d2_ohlc.append((o,h,l,c))
        bed_or_bud.append('BeD')
        trade_entry_price.append(h)
        cond.append(sell['Stock: Condition'][i])

    trans = pd.DataFrame(list(zip(bed_or_bud, cond, d1_date, d1_minute, d1_ohlc, d2_date, d2_minute, d2_ohlc, trade_entry_price)),
                              columns = ['Stock: BuD/BeD','Stock: Condition','D1: Date','D1: Minute','D1: OHLC','D2: Date','D2: Minute','D2: OHLC','Trade: Entry Price'])
    trans = trans.sort_values(by='D1: Date')
    index = {i for i in range(len(trans.index))}
    trans.reset_index(inplace=True)
    trans.drop(columns=['index'], inplace=True)
    
    
    #CODING THE EXIT STRATEGY - STOPLOSS DEFINED AS PREV DAY'S H/L AND RISK:REWARD = 1:2
    trade_exit_date = []
    trade_exit_minute = []
    trade_exit_price = []
    trade_exit_condition = []
    stop_loss = []
    rr = 2

    for i in trans.index:
        date = trans['D2: Date'][i]
        minute = trans['D2: Minute'][i]
        price = trans['Trade: Entry Price'][i]
        daily_j = int(np.where(df['Date']==date)[0])
        minute_j = int(np.where((min_df['Date']==date) & (min_df['Minute']==minute))[0])
        if trans['Stock: BuD/BeD'][i]=='BuD':
            if trans['Stock: Condition'][i]=='HOURLY GAP':
                i_ent_hour = int(np.where((h_df['Hour']==hour_eq(minute))&(h_df['Date']==date))[0])
                stoploss = float(h_df['Low'][i_ent_hour-1])
            else:
                stoploss = float(df['Low'][daily_j-1])
            flag = 0
            for j in range(minute_j+1, min(minute_j+76, len(min_df['Date']))):
                k = int(np.where(df['Date']==min_df['Date'][j])[0])
                hour_i = int(np.where((h_df['Date']==min_df['Date'][j]) & (h_df['Hour']==hour_eq(min_df['Minute'][j])))[0])   
                
                #TRAILING STOPLOSS CONDITION
                if h_df['exp22'][hour_i] < h_df['High'][hour_i]: #checking if price is above 22ema
                    for x in range(hour_i+1, min(hour_i+22, len(h_df['Date']))):
                        y = int(np.where((min_df['Date']==h_df['Date'][x]) & (min_df['Minute']==minute_eq(h_df['Hour'][x])))[0])
                        if h_df['exp22'][x] >= h_df['Low'][x]: #checking if price has fallen below 22ema
                            max_price = price
                            max_z = y
                            for z in range(y, min(y+4, len(min_df['Minute']))):
                                if min_df['High'][z] > max_price:
                                    max_price = min_df['High'][z]
                                    max_z = z
                            trade_exit_date.append(min_df['Date'][max_z])
                            trade_exit_minute.append(min_df['Minute'][max_z])
                            trade_exit_price.append(min_df['High'][max_z])
                            stop_loss.append(h_df['exp22'][max_z])
                            trade_exit_condition.append('TRAILING STOPLOSS')
                            flag = 1
                            break   
                        elif x==hour_i+21 and flag == 0:
                            trade_exit_date.append(min_df['Date'][y])
                            trade_exit_minute.append(min_df['Minute'][y])
                            trade_exit_price.append(min_df['High'][y])
                            stop_loss.append(h_df['exp22'][x])
                            trade_exit_condition.append('TRAILING STOPLOSS')
                            flag = 1
                            break
                        elif x==len(h_df['Date'])-1 and flag == 0:
                            trade_exit_date.append('N/A')
                            trade_exit_minute.append('N/A')
                            trade_exit_price.append('N/A')
                            stop_loss.append('N/A')
                            trade_exit_condition.append('TRAILING STOPLOSS')
                            flag = 1
                            break
                if flag == 1:
                    break
                    
                #RISK REWARD RATIO (REWARD)
                elif (min_df['High'][j] - price >= rr*np.absolute(price - stoploss)):
                    trade_exit_date.append(min_df['Date'][j])
                    trade_exit_minute.append(min_df['Minute'][j])
                    trade_exit_price.append(min_df['High'][j])
                    stop_loss.append(stoploss)
                    trade_exit_condition.append('RISK REWARD RATIO: REWARD')
                    flag = 1
                    break
                    
                #BOLLINGER BANDS
                elif h_df['High'][hour_i] >= h_df['bb_upper'][hour_i]:
                    y = int(np.where((min_df['Date']==h_df['Date'][hour_i]) & (min_df['Minute']==minute_eq(h_df['Hour'][hour_i])))[0])
                    trade_exit_date.append(min_df['Date'][y])
                    trade_exit_minute.append(min_df['Minute'][y])
                    trade_exit_price.append(min_df['High'][y])
                    stop_loss.append('N/A')
                    trade_exit_condition.append('BOLLINGER BANDS')
                    flag = 1
                    break
                    
                #RISK REWARD RATIO (RISK)
                elif (price - min_df['Low'][j] >= np.absolute(price - stoploss)):
                    trade_exit_date.append(min_df['Date'][j])
                    trade_exit_minute.append(min_df['Minute'][j])
                    trade_exit_price.append(min_df['High'][j])
                    stop_loss.append(stoploss)
                    trade_exit_condition.append('RISK REWARD RATIO: RISK')
                    flag = 1
                    break
                    
                #OPPOSING DIVERGENCE IN HOURLY OR DAILY
                elif date_presence(bear_d, min_df['Date'][j]) or date_presence(bear_h, min_df['Date'][j]):
                    trade_exit_date.append(min_df['Date'][j])
                    trade_exit_minute.append(min_df['Minute'][j])
                    trade_exit_price.append(min_df['High'][j])
                    stop_loss.append('N/A')
                    trade_exit_condition.append('OPPOSING DIVERGENCE IN HOURLY OR DAILY')
                    flag = 1
                    break
                            
                #OPPOSING CANDLESTICK ON DAILY
                elif df['candlestick_pattern'][k][-4:] == 'Bear':
                    for a in range(k+1, min(k+6, len(df['Date']))):
                        if df['Low'][a] < df['Low'][k]:
                            x = (np.where(min_df['Date']==df['Date'][a])[0])[-1]
                            trade_exit_date.append(min_df['Date'][x])
                            trade_exit_minute.append(min_df['Minute'][x])
                            trade_exit_price.append(min_df['High'][x])
                            stop_loss.append('N/A')
                            trade_exit_condition.append('OPPOSING CANDLESTICK ON DAILY')
                            flag = 1
                            break
                if flag == 1:
                    break
                    
                #FRIDAY EXIT STRATEGY
                elif min_df['Date'][j].weekday()==4 and min_df['Minute'][j]==24:
                    trade_exit_date.append(min_df['Date'][j])
                    trade_exit_minute.append(min_df['Minute'][j])
                    trade_exit_price.append(min_df['High'][j])
                    stop_loss.append('N/A')
                    trade_exit_condition.append('FRIDAY EXIT')
                    flag = 1
                    break
                    
                #LIMIT OF 3 DAYS REACHED
                elif j==minute_j+75 and flag == 0:
                    trade_exit_date.append(min_df['Date'][j])
                    trade_exit_minute.append(min_df['Minute'][j])
                    trade_exit_price.append(min_df['High'][j])
                    stop_loss.append('N/A')
                    trade_exit_condition.append('3 DAYS FROM ENTRY')
                    flag = 1
                    break
                    
                #END OF DATA REACHED
                elif j==len(min_df['Date'])-1 and flag == 0:
                    trade_exit_date.append('N/A')
                    trade_exit_minute.append('N/A')
                    trade_exit_price.append('N/A')
                    stop_loss.append('N/A')
                    trade_exit_condition.append('HOLD POSITION')
                    break 
                '''
                '''
                                                    
        else:
            if trans['Stock: Condition'][i]=='HOURLY GAP':
                i_ent_hour = int(np.where((h_df['Hour']==hour_eq(minute))&(h_df['Date']==date))[0])
                stoploss = float(h_df['High'][i_ent_hour-1])
            else:
                stoploss = float(df['High'][daily_j-1])
            flag = 0
            for j in range(minute_j+1, min(minute_j+76, len(min_df['Date']))):
                k = int(np.where(df['Date']==min_df['Date'][j])[0])
                hour_i = int(np.where((h_df['Date']==min_df['Date'][j]) & (h_df['Hour']==hour_eq(min_df['Minute'][j])))[0])
                
                #TRAILING STOPLOSS CONDITION
                if h_df['exp22'][hour_i] > h_df['Low'][hour_i]: #checking if price is below 22ema
                    for x in range(hour_i+1, min(hour_i+22, len(h_df['Date']))):
                        y = int(np.where((min_df['Date']==h_df['Date'][x]) & (min_df['Minute']==minute_eq(h_df['Hour'][x])))[0])
                        if h_df['exp22'][x] <= h_df['High'][x]: #checking if price has risen above 22ema
                            min_price = price
                            min_z = y
                            for z in range(y, min(y+4, len(min_df['Minute']))):
                                if min_df['Low'][z] < min_price:
                                    min_price = min_df['Low'][z]
                                    min_z = z
                            trade_exit_date.append(min_df['Date'][min_z])
                            trade_exit_minute.append(min_df['Minute'][min_z])
                            trade_exit_price.append(min_df['Low'][min_z])
                            stop_loss.append(h_df['exp22'][min_z])
                            trade_exit_condition.append('TRAILING STOPLOSS')
                            flag = 1
                            break   
                        elif x==hour_i+21 and flag == 0:
                            trade_exit_date.append(min_df['Date'][y])
                            trade_exit_minute.append(min_df['Minute'][y])
                            trade_exit_price.append(min_df['Low'][y])
                            stop_loss.append(h_df['exp22'][x])
                            trade_exit_condition.append('TRAILING STOPLOSS')
                            flag = 1
                            break
                        elif x==len(h_df['Date'])-1 and flag == 0:
                            trade_exit_date.append('N/A')
                            trade_exit_minute.append('N/A')
                            trade_exit_price.append('N/A')
                            stop_loss.append('N/A')
                            trade_exit_condition.append('TRAILING STOPLOSS')
                            flag = 1
                            break
                if flag == 1:
                    break
                    
                #RISK REWARD RATIO (REWARD)
                elif (price - min_df['Low'][j]) >= rr*np.absolute(price - stoploss):
                    trade_exit_date.append(min_df['Date'][j])
                    trade_exit_minute.append(min_df['Minute'][j])
                    trade_exit_price.append(min_df['Low'][j])
                    stop_loss.append(stoploss)
                    trade_exit_condition.append('RISK REWARD RATIO: REWARD')
                    flag = 1
                    break
                    
                #BOLLINGER BANDS
                elif h_df['Low'][hour_i] <= h_df['bb_lower'][hour_i]:
                    y = int(np.where((min_df['Date']==h_df['Date'][hour_i]) & (min_df['Minute']==minute_eq(h_df['Hour'][hour_i])))[0])
                    trade_exit_date.append(min_df['Date'][y])
                    trade_exit_minute.append(min_df['Minute'][y])
                    trade_exit_price.append(min_df['Low'][y])
                    stop_loss.append('N/A')
                    trade_exit_condition.append('BOLLINGER BANDS')
                    flag = 1
                    break
                    
                #RISK REWARD RATIO (RISK)
                elif (min_df['High'][j] - price) >= np.absolute(price - stoploss):
                    trade_exit_date.append(min_df['Date'][j])
                    trade_exit_minute.append(min_df['Minute'][j])
                    trade_exit_price.append(min_df['Low'][j])
                    stop_loss.append(stoploss)
                    trade_exit_condition.append('RISK REWARD RATIO: RISK')
                    flag = 1
                    break
                    
                #OPPOSING DIVERGENCE IN HOURLY OR DAILY
                elif date_presence(bull_d, min_df['Date'][j]) or date_presence(bull_h, min_df['Date'][j]):
                    trade_exit_date.append(min_df['Date'][j])
                    trade_exit_minute.append(min_df['Minute'][j])
                    trade_exit_price.append(min_df['Low'][j])
                    stop_loss.append('N/A')
                    trade_exit_condition.append('OPPOSING DIVERGENCE IN HOURLY OR DAILY')
                    flag = 1
                    break
                    
                #OPPOSING CANDLESTICK ON DAILY
                elif df['candlestick_pattern'][k][-4:] == 'Bull':
                    for a in range(k+1, min(k+6, len(df['Date']))):
                        if df['High'][a] > df['High'][k]:
                            x = (np.where(min_df['Date']==df['Date'][a])[0])[-1]
                            trade_exit_date.append(min_df['Date'][x])
                            trade_exit_minute.append(min_df['Minute'][x])
                            trade_exit_price.append(min_df['Low'][x])
                            stop_loss.append('N/A')
                            trade_exit_condition.append('OPPOSING CANDLESTICK ON DAILY')
                            flag = 1
                            break
                if flag == 1:
                    break
                    
                #FRIDAY EXIT STRATEGY
                elif min_df['Date'][j].weekday()==4 and min_df['Minute'][j]==24:
                    trade_exit_date.append(min_df['Date'][j])
                    trade_exit_minute.append(min_df['Minute'][j])
                    trade_exit_price.append(min_df['Low'][j])
                    stop_loss.append('N/A')
                    trade_exit_condition.append('FRIDAY EXIT')
                    flag = 1
                    break
                    
                #LIMIT OF 3 DAYS REACHED
                elif j==minute_j+75 and flag == 0:
                    trade_exit_date.append(min_df['Date'][j])
                    trade_exit_minute.append(min_df['Minute'][j])
                    trade_exit_price.append(min_df['Low'][j])
                    stop_loss.append('N/A')
                    trade_exit_condition.append('3 DAYS FROM ENTRY')
                    flag = 1
                    break
                    
                #END OF DATASET REACHED
                elif j==len(min_df['Date'])-1 and flag == 0:
                    trade_exit_date.append('N/A')
                    trade_exit_minute.append('N/A')
                    trade_exit_price.append('N/A')
                    stop_loss.append('N/A')
                    trade_exit_condition.append('HOLD POSITION')
                    break
                '''
                '''

    trans['Trade: Exit Date'] = trade_exit_date
    trans['Trade: Exit Minute'] = trade_exit_minute
    trans['Trade: Exit Price'] = trade_exit_price
    trans['Trade: Exit Condition'] = trade_exit_condition
    trans['Stoploss'] = stop_loss
    PL = []
    for i in trans.index:
        if trans['Trade: Exit Price'][i]!='N/A' and trans['Stock: BuD/BeD'][i]=='BeD':
            pl = round(((trans['Trade: Entry Price'][i] - trans['Trade: Exit Price'][i])*100/trans['Trade: Entry Price'][i]),3)
            PL.append(pl)
        elif trans['Trade: Exit Price'][i]!='N/A' and trans['Stock: BuD/BeD'][i]=='BuD':
            pl = round(((trans['Trade: Exit Price'][i] - trans['Trade: Entry Price'][i])*100/trans['Trade: Entry Price'][i]), 3)
            PL.append(pl)
        else:
            PL.append('N/A')
    trans['Profit/Loss'] = PL
    trans['Stock: Name'] = name
    cn = []

    for i in trans.index:
        if trans['Profit/Loss'][i]!='N/A' and trans['Profit/Loss'][i] >= 0:
            cn.append('YES')
        elif trans['Profit/Loss'][i]!='N/A' and trans['Profit/Loss'][i] < 0:
            cn.append('NO')
        else:
            cn.append('N/A')

    trans['Stock: Correct or Not'] = cn
    cols = trans.columns.tolist()
    cols = cols[-2:] + cols[:-2]
    trans = trans[cols]
    return trans

# %%
all_trans = pd.DataFrame(columns=['Stock: Name','Stock: Correct or Not','Stock: BuD/BeD','Stock: Condition','D1: Date',
                               'D1: Minute','D1: OHLC','D2: Date','D2: Minute','D2: OHLC','Trade: Entry Price',
                              'Trade: Exit Date','Trade: Exit Minute','Trade: Exit Price','Stoploss','Profit/Loss'])


w_ct = 1
w_re = 1
w_dd = 1
w_dg = 1
w_hg = 1

for name in los:
    try:
        print(name)
        print('Weights = '+str(w_ct)+' '+str(w_re)+' '+str(w_dd)+' '+str(w_dg)+' '+str(w_hg))
        trans = trades(name, 1,1,1,1,1)
        name_pl = 0
        for i in trans.index:
            if trans['Trade: Exit Price'][i]!='N/A' and trans['Stock: BuD/BeD'][i] == 'BuD':
                pl = trans['Trade: Exit Price'][i] - trans['Trade: Entry Price'][i]
            elif trans['Trade: Exit Price'][i]!='N/A' and trans['Stock: BuD/BeD'][i]=='BeD':
                pl = trans['Trade: Entry Price'][i] - trans['Trade: Exit Price'][i]
            else:
                pl=0
            name_pl = name_pl + pl
        if np.sum(trans['Trade: Entry Price'])!=0:
            print('Aggregate P/L %age for ' + name + ' = ' + str(round((name_pl*100/np.sum(trans['Trade: Entry Price'])), 3)))
            ct = np.where(trans['Stock: Correct or Not']=='YES')[0]
            print('Success Rate %age for '+ name + ' = ' + str(round(len(ct)/len(trans.index)*100)))
            print('Total Capital for ' + name + ' = ' + str(round(np.sum(trans['Trade: Entry Price']), 3)))
        else:
            print('NO TRADES FOR ' + name)

        all_trans = all_trans.append(trans, ignore_index = True)
        c_ct = len(np.where((all_trans['Stock: Correct or Not']=='YES')&(all_trans['Stock: Condition']=='CONTRA TREND TRADE'))[0])
        c_re = len(np.where((all_trans['Stock: Correct or Not']=='YES')&(all_trans['Stock: Condition']=='RE-ENTRY TRADE'))[0])
        c_dd = len(np.where((all_trans['Stock: Correct or Not']=='YES')&(all_trans['Stock: Condition']=='DAILY DIVERGENCE TRADE'))[0])
        c_dg = len(np.where((all_trans['Stock: Correct or Not']=='YES')&(all_trans['Stock: Condition']=='DAILY GAP'))[0])
        c_hg = len(np.where((all_trans['Stock: Correct or Not']=='YES')&(all_trans['Stock: Condition']=='HOURLY GAP'))[0])
        i_ct = len(np.where((all_trans['Stock: Correct or Not']=='NO')&(all_trans['Stock: Condition']=='CONTRA TREND TRADE'))[0])
        i_re = len(np.where((all_trans['Stock: Correct or Not']=='NO')&(all_trans['Stock: Condition']=='RE-ENTRY TRADE'))[0])
        i_dd = len(np.where((all_trans['Stock: Correct or Not']=='NO')&(all_trans['Stock: Condition']=='DAILY DIVERGENCE TRADE'))[0])
        i_dg = len(np.where((all_trans['Stock: Correct or Not']=='NO')&(all_trans['Stock: Condition']=='DAILY GAP'))[0])
        i_hg = len(np.where((all_trans['Stock: Correct or Not']=='NO')&(all_trans['Stock: Condition']=='HOURLY GAP'))[0])
        w_ct += int((c_ct-i_ct)*100/(len(all_trans.index)+1))
        w_re += int((c_re-i_re)*100/(len(all_trans.index)+1))
        w_dd += int((c_dd-i_dd)*100/(len(all_trans.index)+1))
        w_dg += int((c_dg-i_dg)*100/(len(all_trans.index)+1))
        w_hg += int((c_hg-i_hg)*100/(len(all_trans.index)+1))
        w_ct = max(1, w_ct)
        w_re = max(1, w_re)
        w_dd = max(1, w_dd)
        w_dg = max(1, w_dg)
        w_hg = max(1, w_hg)

        print('\n')

        total_pl = 0
        for i in all_trans.index:
            if all_trans['Trade: Exit Price'][i]!='N/A' and all_trans['Stock: BuD/BeD'][i] == 'BuD':
                temp = all_trans['Trade: Exit Price'][i] - all_trans['Trade: Entry Price'][i]
            elif all_trans['Trade: Exit Price'][i]!='N/A' and all_trans['Stock: BuD/BeD'][i]=='BeD':
                temp = all_trans['Trade: Entry Price'][i] - all_trans['Trade: Exit Price'][i] 
            else:
                temp = 0
            total_pl = total_pl + temp
        if np.sum(all_trans['Trade: Entry Price'])!=0:
            print('Aggregate P/L %age = ' + str(round((total_pl*100/np.sum(all_trans['Trade: Entry Price'])), 3)))
            ct = np.where(all_trans['Stock: Correct or Not']=='YES')[0]
            print('Success Rate %age = '+ str(len(ct)/len(all_trans.index)*100))
            print('Total Capital = ' + str(round(np.sum(all_trans['Trade: Entry Price']), 3)))
        else:
            print('NO TRADES')
        print('\n')
    except:
        continue
        
w_ct = max(1, int(100*w_ct/(w_ct+w_re+w_dd+w_dg+w_hg)))
w_re = max(1, int(100*w_re/(w_ct+w_re+w_dd+w_dg+w_hg)))
w_dd = max(1, int(100*w_dd/(w_ct+w_re+w_dd+w_dg+w_hg)))
w_dg = max(1, int(100*w_dg/(w_ct+w_re+w_dd+w_dg+w_hg)))
w_hg = max(1, int(100*w_hg/(w_ct+w_re+w_dd+w_dg+w_hg)))
print('******************After INITIALISATION****************************')
print(str(w_ct)+','+str(w_re)+','+str(w_dd)+','+str(w_dg)+','+str(w_hg))

print('*******************NOW RUNNING WITH UPDATED WEIGHTS*****************************')
for c in range(20):
    for name in los:
        try:
            print(name)
            #print('Weights = '+str(w_ct)+' '+str(w_re)+' '+str(w_dd)+' '+str(w_dg)+' '+str(w_hg))
            trans = trades(name, w_ct, w_re, w_dd, w_dg, w_hg)
            name_pl = 0
            for i in trans.index:
                if trans['Trade: Exit Price'][i]!='N/A' and trans['Stock: BuD/BeD'][i] == 'BuD':
                    pl = trans['Trade: Exit Price'][i] - trans['Trade: Entry Price'][i]
                elif trans['Trade: Exit Price'][i]!='N/A' and trans['Stock: BuD/BeD'][i]=='BeD':
                    pl = trans['Trade: Entry Price'][i] - trans['Trade: Exit Price'][i]
                else:
                    pl=0
                name_pl = name_pl + pl
            '''if np.sum(trans['Trade: Entry Price'])!=0:
                #print('Aggregate P/L %age for ' + name + ' = ' + str(round((name_pl*100/np.sum(trans['Trade: Entry Price'])), 3)))
                ct = np.where(trans['Stock: Correct or Not']=='YES')[0]
                #print('Success Rate %age for '+ name + ' = ' + str(round(len(ct)/len(trans.index)*100)))
                #print('Total Capital for ' + name + ' = ' + str(round(np.sum(trans['Trade: Entry Price']), 3)))
            else:
                #print('NO TRADES FOR ' + name)'''

            all_trans = all_trans.append(trans, ignore_index = True)
            c_ct = len(np.where((all_trans['Stock: Correct or Not']=='YES')&(all_trans['Stock: Condition']=='CONTRA TREND TRADE'))[0])
            c_re = len(np.where((all_trans['Stock: Correct or Not']=='YES')&(all_trans['Stock: Condition']=='RE-ENTRY TRADE'))[0])
            c_dd = len(np.where((all_trans['Stock: Correct or Not']=='YES')&(all_trans['Stock: Condition']=='DAILY DIVERGENCE TRADE'))[0])
            c_dg = len(np.where((all_trans['Stock: Correct or Not']=='YES')&(all_trans['Stock: Condition']=='DAILY GAP'))[0])
            c_hg = len(np.where((all_trans['Stock: Correct or Not']=='YES')&(all_trans['Stock: Condition']=='HOURLY GAP'))[0])
            i_ct = len(np.where((all_trans['Stock: Correct or Not']=='NO')&(all_trans['Stock: Condition']=='CONTRA TREND TRADE'))[0])
            i_re = len(np.where((all_trans['Stock: Correct or Not']=='NO')&(all_trans['Stock: Condition']=='RE-ENTRY TRADE'))[0])
            i_dd = len(np.where((all_trans['Stock: Correct or Not']=='NO')&(all_trans['Stock: Condition']=='DAILY DIVERGENCE TRADE'))[0])
            i_dg = len(np.where((all_trans['Stock: Correct or Not']=='NO')&(all_trans['Stock: Condition']=='DAILY GAP'))[0])
            i_hg = len(np.where((all_trans['Stock: Correct or Not']=='NO')&(all_trans['Stock: Condition']=='HOURLY GAP'))[0])
            w_ct += int((c_ct-i_ct)*100/(len(all_trans.index)+1))
            w_re += int((c_re-i_re)*100/(len(all_trans.index)+1))
            w_dd += int((c_dd-i_dd)*100/(len(all_trans.index)+1))
            w_dg += int((c_dg-i_dg)*100/(len(all_trans.index)+1))
            w_hg += int((c_hg-i_hg)*100/(len(all_trans.index)+1))
            w_ct = max(1, w_ct)
            w_re = max(1, w_re)
            w_dd = max(1, w_dd)
            w_dg = max(1, w_dg)
            w_hg = max(1, w_hg)

            #print('\n')
            
        except:
            continue
            
    print('*********************Iteration No = '+ str(c)+' **************************')
    total_pl = 0
    for i in all_trans.index:
        if all_trans['Trade: Exit Price'][i]!='N/A' and all_trans['Stock: BuD/BeD'][i] == 'BuD':
            temp = all_trans['Trade: Exit Price'][i] - all_trans['Trade: Entry Price'][i]
        elif all_trans['Trade: Exit Price'][i]!='N/A' and all_trans['Stock: BuD/BeD'][i]=='BeD':
            temp = all_trans['Trade: Entry Price'][i] - all_trans['Trade: Exit Price'][i] 
        else:
            temp = 0
        total_pl = total_pl + temp
    if np.sum(all_trans['Trade: Entry Price'])!=0:
        print('Aggregate P/L %age = ' + str(round((total_pl*100/np.sum(all_trans['Trade: Entry Price'])), 3)))
        ct = np.where(all_trans['Stock: Correct or Not']=='YES')[0]
        print('Success Rate %age = '+ str(len(ct)/len(all_trans.index)*100))
        print('Total Capital = ' + str(round(np.sum(all_trans['Trade: Entry Price']), 3)))
    else:
        print('NO TRADES')
    print('\n')

    w_ct = max(1, int(100*w_ct/(w_ct+w_re+w_dd+w_dg+w_hg)))
    w_re = max(1, int(100*w_re/(w_ct+w_re+w_dd+w_dg+w_hg)))
    w_dd = max(1, int(100*w_dd/(w_ct+w_re+w_dd+w_dg+w_hg)))
    w_dg = max(1, int(100*w_dg/(w_ct+w_re+w_dd+w_dg+w_hg)))
    w_hg = max(1, int(100*w_hg/(w_ct+w_re+w_dd+w_dg+w_hg)))
    
print('******************DONE RUNNING ON UPDATED WEIGHTS****************************')
print(str(w_ct)+','+str(w_re)+','+str(w_dd)+','+str(w_dg)+','+str(w_hg))
# Out:
# AARTIIND.NS
# Weights = 1 1 1 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for AARTIIND.NS = 0.834
# Success Rate %age for AARTIIND.NS = 100
# Total Capital for AARTIIND.NS = 1253.3
#
#
# Aggregate P/L %age = 0.834
# Success Rate %age = 100.0
# Total Capital = 1253.3
#
#
# ACC.NS
# Weights = 1 51 1 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ACC.NS = 1.038
# Success Rate %age for ACC.NS = 100
# Total Capital for ACC.NS = 9180.1
#
#
# Aggregate P/L %age = 1.013
# Success Rate %age = 100.0
# Total Capital = 10433.4
#
#
# ADANIENT.NS
# Weights = 1 108 29 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ADANIENT.NS = 0.373
# Success Rate %age for ADANIENT.NS = 67
# Total Capital for ADANIENT.NS = 3070.95
#
#
# Aggregate P/L %age = 0.867
# Success Rate %age = 88.88888888888889
# Total Capital = 13504.35
#
#
# ADANIPORTS.NS
# Weights = 1 168 49 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ADANIPORTS.NS = 1.079
# Success Rate %age for ADANIPORTS.NS = 67
# Total Capital for ADANIPORTS.NS = 2210.65
#
#
# Aggregate P/L %age = 0.897
# Success Rate %age = 83.33333333333334
# Total Capital = 15715.0
#
#
# ALKEM.NS
# Weights = 1 221 72 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ALKEM.NS = 4.296
# Success Rate %age for ALKEM.NS = 100
# Total Capital for ALKEM.NS = 2768.0
#
#
# Aggregate P/L %age = 1.406
# Success Rate %age = 84.61538461538461
# Total Capital = 18483.0
#
#
# AMARAJABAT.NS
# Weights = 1 278 93 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for AMARAJABAT.NS = 0.346
# Success Rate %age for AMARAJABAT.NS = 100
# Total Capital for AMARAJABAT.NS = 780.0
#
#
# Aggregate P/L %age = 1.363
# Success Rate %age = 85.71428571428571
# Total Capital = 19263.0
#
#
# AMBUJACEM.NS
# Weights = 1 331 119 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for AMBUJACEM.NS = 1.435
# Success Rate %age for AMBUJACEM.NS = 100
# Total Capital for AMBUJACEM.NS = 1195.4
#
#
# Aggregate P/L %age = 1.367
# Success Rate %age = 88.88888888888889
# Total Capital = 20458.4
#
#
# APLLTD.NS
# Weights = 1 388 145 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for APLLTD.NS = 1.397
# Success Rate %age for APLLTD.NS = 100
# Total Capital for APLLTD.NS = 4793.85
#
#
# Aggregate P/L %age = 1.373
# Success Rate %age = 91.30434782608695
# Total Capital = 25252.25
#
#
# APOLLOHOSP.NS
# Weights = 1 442 178 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for APOLLOHOSP.NS = 2.626
# Success Rate %age for APOLLOHOSP.NS = 86
# Total Capital for APOLLOHOSP.NS = 20974.45
#
#
# Aggregate P/L %age = 1.942
# Success Rate %age = 90.0
# Total Capital = 46226.7
#
#
# APOLLOTYRE.NS
# Weights = 1 493 203 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for APOLLOTYRE.NS = 3.845
# Success Rate %age for APOLLOTYRE.NS = 100
# Total Capital for APOLLOTYRE.NS = 462.95
#
#
# Aggregate P/L %age = 1.96
# Success Rate %age = 90.625
# Total Capital = 46689.65
#
#
# ASHOKLEY.NS
# Weights = 1 541 230 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ASHOKLEY.NS = 1.512
# Success Rate %age for ASHOKLEY.NS = 40
# Total Capital for ASHOKLEY.NS = 575.25
#
#
# Aggregate P/L %age = 1.955
# Success Rate %age = 83.78378378378379
# Total Capital = 47264.9
#
#
# ASIANPAINT.NS
# Weights = 1 583 253 1 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ASIANPAINT.NS = 1.903
# Success Rate %age for ASIANPAINT.NS = 100
# Total Capital for ASIANPAINT.NS = 10394.35
#
#
# Aggregate P/L %age = 1.946
# Success Rate %age = 85.36585365853658
# Total Capital = 57659.25
#
#
# AUBANK.NS
# Weights = 1 623 276 3 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for AUBANK.NS = 0.164
# Success Rate %age for AUBANK.NS = 80
# Total Capital for AUBANK.NS = 5692.6
#
#
# Aggregate P/L %age = 1.786
# Success Rate %age = 84.78260869565217
# Total Capital = 63351.85
#
#
# AUROPHARMA.NS
# Weights = 1 665 299 3 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for AUROPHARMA.NS = 1.384
# Success Rate %age for AUROPHARMA.NS = 100
# Total Capital for AUROPHARMA.NS = 986.3
#
#
# Aggregate P/L %age = 1.779
# Success Rate %age = 85.1063829787234
# Total Capital = 64338.15
#
#
# AXISBANK.NS
# Weights = 1 706 321 5 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for AXISBANK.NS = 0.849
# Success Rate %age for AXISBANK.NS = 88
# Total Capital for AXISBANK.NS = 5719.7
#
#
# Aggregate P/L %age = 1.703
# Success Rate %age = 85.45454545454545
# Total Capital = 70057.85
#
#
# BAJAJFINSV.NS
# Weights = 1 747 344 6 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BAJAJFINSV.NS = 3.18
# Success Rate %age for BAJAJFINSV.NS = 100
# Total Capital for BAJAJFINSV.NS = 31579.2
#
#
# Aggregate P/L %age = 2.162
# Success Rate %age = 86.20689655172413
# Total Capital = 101637.05
#
#
# BAJAJ-AUTO.NS
# Weights = 1 787 367 9 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BAJAJ-AUTO.NS = 1.214
# Success Rate %age for BAJAJ-AUTO.NS = 83
# Total Capital for BAJAJ-AUTO.NS = 22648.1
#
#
# Aggregate P/L %age = 1.99
# Success Rate %age = 85.9375
# Total Capital = 124285.15
#
#
# BAJFINANCE.NS
# Weights = 1 823 393 12 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BAJFINANCE.NS = 2.822
# Success Rate %age for BAJFINANCE.NS = 100
# Total Capital for BAJFINANCE.NS = 30432.95
#
#
# Aggregate P/L %age = 2.153
# Success Rate %age = 87.14285714285714
# Total Capital = 154718.1
#
#
# BALKRISIND.NS
# Weights = 1 858 418 20 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BALKRISIND.NS = 0.625
# Success Rate %age for BALKRISIND.NS = 100
# Total Capital for BALKRISIND.NS = 3266.1
#
#
# Aggregate P/L %age = 2.122
# Success Rate %age = 87.5
# Total Capital = 157984.2
#
#
# BANDHANBNK.NS
# Weights = 1 893 444 28 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BANDHANBNK.NS = 1.85
# Success Rate %age for BANDHANBNK.NS = 67
# Total Capital for BANDHANBNK.NS = 978.25
#
#
# Aggregate P/L %age = 2.12
# Success Rate %age = 86.66666666666667
# Total Capital = 158962.45
#
#
# BANKBARODA.NS
# Weights = 1 928 470 34 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BANKBARODA.NS = 2.902
# Success Rate %age for BANKBARODA.NS = 100
# Total Capital for BANKBARODA.NS = 198.15
#
#
# Aggregate P/L %age = 2.121
# Success Rate %age = 87.17948717948718
# Total Capital = 159160.6
#
#
# ^NSEBANK
# Weights = 1 962 496 42 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ^NSEBANK = 1.196
# Success Rate %age for ^NSEBANK = 100
# Total Capital for ^NSEBANK = 164783.1
#
#
# Aggregate P/L %age = 1.65
# Success Rate %age = 87.95180722891565
# Total Capital = 323943.7
#
#
# BATAINDIA.NS
# Weights = 1 995 523 51 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BATAINDIA.NS = -0.305
# Success Rate %age for BATAINDIA.NS = 0
# Total Capital for BATAINDIA.NS = 4343.3
#
#
# Aggregate P/L %age = 1.624
# Success Rate %age = 84.88372093023256
# Total Capital = 328287.0
#
#
# BEL.NS
# Weights = 1 1027 548 60 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BEL.NS = 5.403
# Success Rate %age for BEL.NS = 100
# Total Capital for BEL.NS = 150.85
#
#
# Aggregate P/L %age = 1.626
# Success Rate %age = 85.0574712643678
# Total Capital = 328437.85
#
#
# BERGEPAINT.NS
# Weights = 1 1058 573 70 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BERGEPAINT.NS = 1.01
# Success Rate %age for BERGEPAINT.NS = 67
# Total Capital for BERGEPAINT.NS = 2179.2
#
#
# Aggregate P/L %age = 1.622
# Success Rate %age = 84.44444444444444
# Total Capital = 330617.05
#
#
# BHARATFORG.NS
# Weights = 1 1088 599 78 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BHARATFORG.NS = 2.167
# Success Rate %age for BHARATFORG.NS = 100
# Total Capital for BHARATFORG.NS = 1237.0
#
#
# Aggregate P/L %age = 1.624
# Success Rate %age = 84.78260869565217
# Total Capital = 331854.05
#
#
# BHARTIARTL.NS
# Weights = 1 1118 626 86 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BHARTIARTL.NS = -0.079
# Success Rate %age for BHARTIARTL.NS = 33
# Total Capital for BHARTIARTL.NS = 1637.35
#
#
# Aggregate P/L %age = 1.616
# Success Rate %age = 83.15789473684211
# Total Capital = 333491.4
#
#
# BHEL.NS
# Weights = 1 1147 651 95 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BHEL.NS = 6.097
# Success Rate %age for BHEL.NS = 100
# Total Capital for BHEL.NS = 95.95
#
#
# Aggregate P/L %age = 1.617
# Success Rate %age = 83.50515463917526
# Total Capital = 333587.35
#
#
# BIOCON.NS
# Weights = 1 1176 675 105 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BIOCON.NS = 1.62
# Success Rate %age for BIOCON.NS = 100
# Total Capital for BIOCON.NS = 799.45
#
#
# Aggregate P/L %age = 1.617
# Success Rate %age = 83.83838383838383
# Total Capital = 334386.8
#
#
# BOSCHLTD.NS
# Weights = 1 1206 699 116 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BOSCHLTD.NS = 3.065
# Success Rate %age for BOSCHLTD.NS = 100
# Total Capital for BOSCHLTD.NS = 14921.35
#
#
# Aggregate P/L %age = 1.679
# Success Rate %age = 84.0
# Total Capital = 349308.15
#
#
# BPCL.NS
# Weights = 1 1236 722 126 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for BPCL.NS = 0.529
# Success Rate %age for BPCL.NS = 67
# Total Capital for BPCL.NS = 1294.65
#
#
# Aggregate P/L %age = 1.675
# Success Rate %age = 83.49514563106796
# Total Capital = 350602.8
#
#
# BRITANNIA.NS
# Weights = 1 1266 746 136 1
# [*********************100%***********************]  1 of 1 completed
# CADILAHC.NS
# Weights = 1 1266 746 136 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for CADILAHC.NS = 0.301
# Success Rate %age for CADILAHC.NS = 100
# Total Capital for CADILAHC.NS = 432.0
#
#
# Aggregate P/L %age = 1.673
# Success Rate %age = 83.65384615384616
# Total Capital = 351034.8
#
#
# CANBK.NS
# Weights = 1 1296 770 146 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for CANBK.NS = 2.256
# Success Rate %age for CANBK.NS = 100
# Total Capital for CANBK.NS = 310.3
#
#
# Aggregate P/L %age = 1.674
# Success Rate %age = 83.9622641509434
# Total Capital = 351345.1
#
#
# CHOLAFIN.NS
# Weights = 1 1326 795 156 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for CHOLAFIN.NS = 2.522
# Success Rate %age for CHOLAFIN.NS = 100
# Total Capital for CHOLAFIN.NS = 1665.6
#
#
# Aggregate P/L %age = 1.678
# Success Rate %age = 84.40366972477065
# Total Capital = 353010.7
#
#
# CIPLA.NS
# Weights = 1 1357 820 166 1
# [*********************100%***********************]  1 of 1 completed
# NO TRADES FOR CIPLA.NS
#
#
# Aggregate P/L %age = 1.678
# Success Rate %age = 84.40366972477065
# Total Capital = 353010.7
#
#
# COALINDIA.NS
# Weights = 1 1388 845 176 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for COALINDIA.NS = 1.133
# Success Rate %age for COALINDIA.NS = 100
# Total Capital for COALINDIA.NS = 128.0
#
#
# Aggregate P/L %age = 1.677
# Success Rate %age = 84.54545454545455
# Total Capital = 353138.7
#
#
# COFORGE.NS
# Weights = 1 1419 871 185 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for COFORGE.NS = 5.365
# Success Rate %age for COFORGE.NS = 89
# Total Capital for COFORGE.NS = 24865.3
#
#
# Aggregate P/L %age = 1.92
# Success Rate %age = 84.87394957983193
# Total Capital = 378004.0
#
#
# COLPAL.NS
# Weights = 1 1450 898 194 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for COLPAL.NS = 0.802
# Success Rate %age for COLPAL.NS = 100
# Total Capital for COLPAL.NS = 6133.55
#
#
# Aggregate P/L %age = 1.902
# Success Rate %age = 85.36585365853658
# Total Capital = 384137.55
#
#
# CONCOR.NS
# Weights = 1 1482 925 203 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for CONCOR.NS = 2.514
# Success Rate %age for CONCOR.NS = 100
# Total Capital for CONCOR.NS = 1141.8
#
#
# Aggregate P/L %age = 1.904
# Success Rate %age = 85.6
# Total Capital = 385279.35
#
#
# CUB.NS
# Weights = 1 1515 951 212 1
# [*********************100%***********************]  1 of 1 completed
# CUMMINSIND.NS
# Weights = 1 1515 951 212 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for CUMMINSIND.NS = 4.618
# Success Rate %age for CUMMINSIND.NS = 100
# Total Capital for CUMMINSIND.NS = 4185.85
#
#
# Aggregate P/L %age = 1.933
# Success Rate %age = 86.15384615384616
# Total Capital = 389465.2
#
#
# DABUR.NS
# Weights = 1 1549 977 221 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for DABUR.NS = 1.057
# Success Rate %age for DABUR.NS = 83
# Total Capital for DABUR.NS = 3182.65
#
#
# Aggregate P/L %age = 1.926
# Success Rate %age = 86.02941176470588
# Total Capital = 392647.85
#
#
# DEEPAKNTR.NS
# Weights = 1 1583 1003 231 1
# [*********************100%***********************]  1 of 1 completed
# DIVISLAB.NS
# Weights = 1 1583 1003 231 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for DIVISLAB.NS = 1.9
# Success Rate %age for DIVISLAB.NS = 100
# Total Capital for DIVISLAB.NS = 14874.6
#
#
# Aggregate P/L %age = 1.925
# Success Rate %age = 86.42857142857143
# Total Capital = 407522.45
#
#
# DLF.NS
# Weights = 1 1617 1029 240 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for DLF.NS = 0.913
# Success Rate %age for DLF.NS = 100
# Total Capital for DLF.NS = 919.8
#
#
# Aggregate P/L %age = 1.923
# Success Rate %age = 86.7132867132867
# Total Capital = 408442.25
#
#
# DRREDDY.NS
# Weights = 1 1651 1056 250 1
# [*********************100%***********************]  1 of 1 completed
# EICHERMOT.NS
# Weights = 1 1651 1056 250 1
# [*********************100%***********************]  1 of 1 completed
# ESCORTS.NS
# Weights = 1 1651 1056 250 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ESCORTS.NS = 2.605
# Success Rate %age for ESCORTS.NS = 100
# Total Capital for ESCORTS.NS = 3992.45
#
#
# Aggregate P/L %age = 1.929
# Success Rate %age = 86.98630136986301
# Total Capital = 412434.7
#
#
# EXIDEIND.NS
# Weights = 1 1686 1082 260 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for EXIDEIND.NS = 1.561
# Success Rate %age for EXIDEIND.NS = 100
# Total Capital for EXIDEIND.NS = 185.75
#
#
# Aggregate P/L %age = 1.929
# Success Rate %age = 87.07482993197279
# Total Capital = 412620.45
#
#
# FEDERALBNK.NS
# Weights = 1 1721 1108 271 1
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS
# Weights = 1 1721 1108 271 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for GAIL.NS = 3.694
# Success Rate %age for GAIL.NS = 100
# Total Capital for GAIL.NS = 147.55
#
#
# Aggregate P/L %age = 1.93
# Success Rate %age = 87.16216216216216
# Total Capital = 412768.0
#
#
# GLENMARK.NS
# Weights = 1 1755 1134 282 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for GLENMARK.NS = 2.911
# Success Rate %age for GLENMARK.NS = 100
# Total Capital for GLENMARK.NS = 1076.9
#
#
# Aggregate P/L %age = 1.932
# Success Rate %age = 87.33333333333333
# Total Capital = 413844.9
#
#
# GMRINFRA.NS
# Weights = 1 1789 1161 293 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for GMRINFRA.NS = 7.036
# Success Rate %age for GMRINFRA.NS = 100
# Total Capital for GMRINFRA.NS = 23.45
#
#
# Aggregate P/L %age = 1.933
# Success Rate %age = 87.41721854304636
# Total Capital = 413868.35
#
#
# GODREJCP.NS
# Weights = 1 1823 1188 304 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for GODREJCP.NS = 2.425
# Success Rate %age for GODREJCP.NS = 100
# Total Capital for GODREJCP.NS = 3631.55
#
#
# Aggregate P/L %age = 1.937
# Success Rate %age = 87.82051282051282
# Total Capital = 417499.9
#
#
# GODREJPROP.NS
# Weights = 1 1856 1216 316 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for GODREJPROP.NS = 1.53
# Success Rate %age for GODREJPROP.NS = 100
# Total Capital for GODREJPROP.NS = 4143.3
#
#
# Aggregate P/L %age = 1.933
# Success Rate %age = 88.0503144654088
# Total Capital = 421643.2
#
#
# GRANULES.NS
# Weights = 1 1889 1245 328 1
# [*********************100%***********************]  1 of 1 completed
# GRASIM.NS
# Weights = 1 1889 1245 328 1
# [*********************100%***********************]  1 of 1 completed
# NO TRADES FOR GRASIM.NS
#
#
# Aggregate P/L %age = 1.933
# Success Rate %age = 88.0503144654088
# Total Capital = 421643.2
#
#
# HAVELLS.NS
# Weights = 1 1922 1274 340 1
# [*********************100%***********************]  1 of 1 completed
# HCLTECH.NS
# Weights = 1 1922 1274 340 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for HCLTECH.NS = 1.638
# Success Rate %age for HCLTECH.NS = 100
# Total Capital for HCLTECH.NS = 2842.6
#
#
# Aggregate P/L %age = 1.931
# Success Rate %age = 88.27160493827161
# Total Capital = 424485.8
#
#
# HDFC.NS
# Weights = 1 1955 1302 353 1
# [*********************100%***********************]  1 of 1 completed
# HDFCBANK.NS
# Weights = 1 1955 1302 353 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for HDFCBANK.NS = 1.701
# Success Rate %age for HDFCBANK.NS = 75
# Total Capital for HDFCBANK.NS = 6027.5
#
#
# Aggregate P/L %age = 1.928
# Success Rate %age = 87.95180722891565
# Total Capital = 430513.3
#
#
# HDFCLIFE.NS
# Weights = 1 1987 1330 366 1
# [*********************100%***********************]  1 of 1 completed
# NO TRADES FOR HDFCLIFE.NS
#
#
# Aggregate P/L %age = 1.928
# Success Rate %age = 87.95180722891565
# Total Capital = 430513.3
#
#
# HEROMOTOCO.NS
# Weights = 1 2019 1358 379 1
# [*********************100%***********************]  1 of 1 completed
# HINDALCO.NS
# Weights = 1 2019 1358 379 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for HINDALCO.NS = 0.046
# Success Rate %age for HINDALCO.NS = 57
# Total Capital for HINDALCO.NS = 2588.55
#
#
# Aggregate P/L %age = 1.917
# Success Rate %age = 86.70520231213872
# Total Capital = 433101.85
#
#
# HINDPETRO.NS
# Weights = 1 2051 1386 389 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for HINDPETRO.NS = -1.441
# Success Rate %age for HINDPETRO.NS = 0
# Total Capital for HINDPETRO.NS = 235.95
#
#
# Aggregate P/L %age = 1.915
# Success Rate %age = 86.20689655172413
# Total Capital = 433337.8
#
#
# HINDUNILVR.NS
# Weights = 1 2083 1414 399 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for HINDUNILVR.NS = 0.577
# Success Rate %age for HINDUNILVR.NS = 67
# Total Capital for HINDUNILVR.NS = 7033.25
#
#
# Aggregate P/L %age = 1.893
# Success Rate %age = 85.87570621468926
# Total Capital = 440371.05
#
#
# IBULHSGFIN.NS
# Weights = 1 2114 1442 409 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for IBULHSGFIN.NS = 3.887
# Success Rate %age for IBULHSGFIN.NS = 100
# Total Capital for IBULHSGFIN.NS = 944.25
#
#
# Aggregate P/L %age = 1.898
# Success Rate %age = 86.26373626373626
# Total Capital = 441315.3
#
#
# ICICIBANK.NS
# Weights = 1 2145 1469 421 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ICICIBANK.NS = 1.486
# Success Rate %age for ICICIBANK.NS = 100
# Total Capital for ICICIBANK.NS = 1740.0
#
#
# Aggregate P/L %age = 1.896
# Success Rate %age = 86.48648648648648
# Total Capital = 443055.3
#
#
# ICICIGI.NS
# Weights = 1 2175 1496 433 1
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS
# Weights = 1 2175 1496 433 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ICICIPRULI.NS = 2.158
# Success Rate %age for ICICIPRULI.NS = 100
# Total Capital for ICICIPRULI.NS = 2064.55
#
#
# Aggregate P/L %age = 1.897
# Success Rate %age = 86.77248677248677
# Total Capital = 445119.85
#
#
# IDEA.NS
# Weights = 1 2206 1523 445 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for IDEA.NS = 2.426
# Success Rate %age for IDEA.NS = 100
# Total Capital for IDEA.NS = 28.85
#
#
# Aggregate P/L %age = 1.897
# Success Rate %age = 86.97916666666666
# Total Capital = 445148.7
#
#
# IDFCFIRSTB.NS
# Weights = 1 2236 1550 457 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for IDFCFIRSTB.NS = 1.734
# Success Rate %age for IDFCFIRSTB.NS = 80
# Total Capital for IDFCFIRSTB.NS = 276.8
#
#
# Aggregate P/L %age = 1.897
# Success Rate %age = 86.80203045685279
# Total Capital = 445425.5
#
#
# IGL.NS
# Weights = 1 2266 1577 469 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for IGL.NS = -0.685
# Success Rate %age for IGL.NS = 0
# Total Capital for IGL.NS = 1043.15
#
#
# Aggregate P/L %age = 1.891
# Success Rate %age = 85.92964824120602
# Total Capital = 446468.65
#
#
# INDIGO.NS
# Weights = 1 2296 1604 481 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for INDIGO.NS = 2.436
# Success Rate %age for INDIGO.NS = 100
# Total Capital for INDIGO.NS = 3358.0
#
#
# Aggregate P/L %age = 1.895
# Success Rate %age = 86.06965174129353
# Total Capital = 449826.65
#
#
# INDUSINDBK.NS
# Weights = 1 2326 1631 493 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for INDUSINDBK.NS = 2.433
# Success Rate %age for INDUSINDBK.NS = 100
# Total Capital for INDUSINDBK.NS = 9556.1
#
#
# Aggregate P/L %age = 1.906
# Success Rate %age = 86.7298578199052
# Total Capital = 459382.75
#
#
# INFY.NS
# Weights = 1 2355 1658 506 1
# [*********************100%***********************]  1 of 1 completed
# IOC.NS
# Weights = 1 2355 1658 506 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for IOC.NS = 0.493
# Success Rate %age for IOC.NS = 80
# Total Capital for IOC.NS = 497.1
#
#
# Aggregate P/L %age = 1.905
# Success Rate %age = 86.57407407407408
# Total Capital = 459879.85
#
#
# IRCTC.NS
# Weights = 1 2384 1684 519 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for IRCTC.NS = 1.498
# Success Rate %age for IRCTC.NS = 100
# Total Capital for IRCTC.NS = 8472.15
#
#
# Aggregate P/L %age = 1.897
# Success Rate %age = 86.87782805429865
# Total Capital = 468352.0
#
#
# ITC.NS
# Weights = 1 2413 1711 532 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ITC.NS = 0.925
# Success Rate %age for ITC.NS = 100
# Total Capital for ITC.NS = 621.45
#
#
# Aggregate P/L %age = 1.896
# Success Rate %age = 87.05357142857143
# Total Capital = 468973.45
#
#
# JINDALSTEL.NS
# Weights = 1 2442 1738 546 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for JINDALSTEL.NS = 3.686
# Success Rate %age for JINDALSTEL.NS = 100
# Total Capital for JINDALSTEL.NS = 2190.65
#
#
# Aggregate P/L %age = 1.904
# Success Rate %age = 87.39130434782608
# Total Capital = 471164.1
#
#
# JSWSTEEL.NS
# Weights = 1 2471 1764 560 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for JSWSTEEL.NS = 1.139
# Success Rate %age for JSWSTEEL.NS = 50
# Total Capital for JSWSTEEL.NS = 851.65
#
#
# Aggregate P/L %age = 1.903
# Success Rate %age = 87.06896551724138
# Total Capital = 472015.75
#
#
# JUBLFOOD.NS
# Weights = 1 2501 1790 574 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for JUBLFOOD.NS = 1.124
# Success Rate %age for JUBLFOOD.NS = 100
# Total Capital for JUBLFOOD.NS = 8768.45
#
#
# Aggregate P/L %age = 1.889
# Success Rate %age = 87.2340425531915
# Total Capital = 480784.2
#
#
# KOTAKBANK.NS
# Weights = 1 2530 1816 588 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for KOTAKBANK.NS = 1.003
# Success Rate %age for KOTAKBANK.NS = 100
# Total Capital for KOTAKBANK.NS = 3553.45
#
#
# Aggregate P/L %age = 1.882
# Success Rate %age = 87.34177215189874
# Total Capital = 484337.65
#
#
# LICHSGFIN.NS
# Weights = 1 2559 1843 602 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for LICHSGFIN.NS = 0.695
# Success Rate %age for LICHSGFIN.NS = 75
# Total Capital for LICHSGFIN.NS = 1741.4
#
#
# Aggregate P/L %age = 1.878
# Success Rate %age = 87.13692946058092
# Total Capital = 486079.05
#
#
# LT.NS
# Weights = 1 2588 1870 615 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for LT.NS = 1.883
# Success Rate %age for LT.NS = 100
# Total Capital for LT.NS = 4152.7
#
#
# Aggregate P/L %age = 1.878
# Success Rate %age = 87.29508196721312
# Total Capital = 490231.75
#
#
# LTI.NS
# Weights = 1 2617 1897 628 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for LTI.NS = 2.431
# Success Rate %age for LTI.NS = 100
# Total Capital for LTI.NS = 16082.0
#
#
# Aggregate P/L %age = 1.896
# Success Rate %age = 87.5
# Total Capital = 506313.75
#
#
# LTTS.NS
# Weights = 1 2646 1924 641 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for LTTS.NS = 2.117
# Success Rate %age for LTTS.NS = 100
# Total Capital for LTTS.NS = 10324.3
#
#
# Aggregate P/L %age = 1.9
# Success Rate %age = 87.6984126984127
# Total Capital = 516638.05
#
#
# LUPIN.NS
# Weights = 1 2675 1952 654 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for LUPIN.NS = 0.048
# Success Rate %age for LUPIN.NS = 33
# Total Capital for LUPIN.NS = 3095.5
#
#
# Aggregate P/L %age = 1.889
# Success Rate %age = 87.05882352941177
# Total Capital = 519733.55
#
#
# MANAPPURAM.NS
# Weights = 1 2704 1978 667 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for MANAPPURAM.NS = 1.436
# Success Rate %age for MANAPPURAM.NS = 100
# Total Capital for MANAPPURAM.NS = 480.35
#
#
# Aggregate P/L %age = 1.889
# Success Rate %age = 87.20930232558139
# Total Capital = 520213.9
#
#
# MARICO.NS
# Weights = 1 2733 2005 680 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for MARICO.NS = 0.528
# Success Rate %age for MARICO.NS = 50
# Total Capital for MARICO.NS = 814.3
#
#
# Aggregate P/L %age = 1.887
# Success Rate %age = 86.92307692307692
# Total Capital = 521028.2
#
#
# MARUTI.NS
# Weights = 1 2762 2032 693 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for MARUTI.NS = 0.035
# Success Rate %age for MARUTI.NS = 75
# Total Capital for MARUTI.NS = 27168.35
#
#
# Aggregate P/L %age = 1.795
# Success Rate %age = 86.74242424242425
# Total Capital = 548196.55
#
#
# MCDOWELL-N.NS
# Weights = 1 2791 2059 705 1
# [*********************100%***********************]  1 of 1 completed
# MGL.NS
# Weights = 1 2791 2059 705 1
# [*********************100%***********************]  1 of 1 completed
# MINDTREE.NS
# Weights = 1 2791 2059 705 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for MINDTREE.NS = 1.006
# Success Rate %age for MINDTREE.NS = 100
# Total Capital for MINDTREE.NS = 4050.2
#
#
# Aggregate P/L %age = 1.789
# Success Rate %age = 86.8421052631579
# Total Capital = 552246.75
#
#
# MOTHERSUMI.NS
# Weights = 1 2820 2086 717 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for MOTHERSUMI.NS = 2.132
# Success Rate %age for MOTHERSUMI.NS = 100
# Total Capital for MOTHERSUMI.NS = 1092.8
#
#
# Aggregate P/L %age = 1.79
# Success Rate %age = 87.08487084870849
# Total Capital = 553339.55
#
#
# MPHASIS.NS
# Weights = 1 2850 2112 729 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for MPHASIS.NS = 1.912
# Success Rate %age for MPHASIS.NS = 83
# Total Capital for MPHASIS.NS = 10481.0
#
#
# Aggregate P/L %age = 1.792
# Success Rate %age = 87.00361010830325
# Total Capital = 563820.55
#
#
# MRF.NS
# Weights = 1 2880 2138 741 1
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS
# Weights = 1 2880 2138 741 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for MUTHOOTFIN.NS = 1.532
# Success Rate %age for MUTHOOTFIN.NS = 100
# Total Capital for MUTHOOTFIN.NS = 3471.8
#
#
# Aggregate P/L %age = 1.79
# Success Rate %age = 87.14285714285714
# Total Capital = 567292.35
#
#
# M&M.NS
# Weights = 1 2910 2164 753 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for M&M.NS = 1.301
# Success Rate %age for M&M.NS = 100
# Total Capital for M&M.NS = 3110.05
#
#
# Aggregate P/L %age = 1.788
# Success Rate %age = 87.32394366197182
# Total Capital = 570402.4
#
#
# M&MFIN.NS
# Weights = 1 2940 2191 765 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for M&MFIN.NS = 3.527
# Success Rate %age for M&MFIN.NS = 100
# Total Capital for M&MFIN.NS = 371.45
#
#
# Aggregate P/L %age = 1.789
# Success Rate %age = 87.41258741258741
# Total Capital = 570773.85
#
#
# NATIONALUM.NS
# Weights = 1 2970 2217 777 1
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS
# Weights = 1 2970 2217 777 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for NAUKRI.NS = 0.424
# Success Rate %age for NAUKRI.NS = 100
# Total Capital for NAUKRI.NS = 4924.0
#
#
# Aggregate P/L %age = 1.777
# Success Rate %age = 87.45644599303137
# Total Capital = 575697.85
#
#
# NAVINFLUOR.NS
# Weights = 1 3000 2243 789 1
# [*********************100%***********************]  1 of 1 completed
# NCC.NS
# Weights = 1 3000 2243 789 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for NCC.NS = 1.686
# Success Rate %age for NCC.NS = 100
# Total Capital for NCC.NS = 489.4
#
#
# Aggregate P/L %age = 1.777
# Success Rate %age = 87.71331058020478
# Total Capital = 576187.25
#
#
# NESTLEIND.NS
# Weights = 1 3030 2269 802 1
# [*********************100%***********************]  1 of 1 completed
# NO TRADES FOR NESTLEIND.NS
#
#
# Aggregate P/L %age = 1.777
# Success Rate %age = 87.71331058020478
# Total Capital = 576187.25
#
#
# ^NSEI
# Weights = 1 3060 2295 815 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ^NSEI = 0.721
# Success Rate %age for ^NSEI = 75
# Total Capital for ^NSEI = 118512.3
#
#
# Aggregate P/L %age = 1.597
# Success Rate %age = 87.37541528239203
# Total Capital = 694699.55
#
#
# NMDC.NS
# Weights = 1 3090 2320 828 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for NMDC.NS = 1.78
# Success Rate %age for NMDC.NS = 100
# Total Capital for NMDC.NS = 699.3
#
#
# Aggregate P/L %age = 1.597
# Success Rate %age = 87.58169934640523
# Total Capital = 695398.85
#
#
# NTPC.NS
# Weights = 1 3120 2345 842 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for NTPC.NS = 2.814
# Success Rate %age for NTPC.NS = 80
# Total Capital for NTPC.NS = 517.0
#
#
# Aggregate P/L %age = 1.598
# Success Rate %age = 87.45980707395499
# Total Capital = 695915.85
#
#
# ONGC.NS
# Weights = 1 3151 2370 856 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ONGC.NS = 0.679
# Success Rate %age for ONGC.NS = 80
# Total Capital for ONGC.NS = 552.2
#
#
# Aggregate P/L %age = 1.597
# Success Rate %age = 87.34177215189874
# Total Capital = 696468.05
#
#
# PAGEIND.NS
# Weights = 1 3181 2395 869 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for PAGEIND.NS = 1.128
# Success Rate %age for PAGEIND.NS = 86
# Total Capital for PAGEIND.NS = 205732.501
#
#
# Aggregate P/L %age = 1.49
# Success Rate %age = 87.30650154798761
# Total Capital = 902200.551
#
#
# PEL.NS
# Weights = 1 3212 2420 882 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for PEL.NS = 1.691
# Success Rate %age for PEL.NS = 100
# Total Capital for PEL.NS = 3752.5
#
#
# Aggregate P/L %age = 1.491
# Success Rate %age = 87.38461538461539
# Total Capital = 905953.051
#
#
# PETRONET.NS
# Weights = 1 3243 2445 895 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for PETRONET.NS = 3.913
# Success Rate %age for PETRONET.NS = 50
# Total Capital for PETRONET.NS = 463.85
#
#
# Aggregate P/L %age = 1.492
# Success Rate %age = 87.1559633027523
# Total Capital = 906416.901
#
#
# PFIZER.NS
# Weights = 1 3274 2470 908 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for PFIZER.NS = 1.179
# Success Rate %age for PFIZER.NS = 67
# Total Capital for PFIZER.NS = 13333.0
#
#
# Aggregate P/L %age = 1.488
# Success Rate %age = 86.96969696969697
# Total Capital = 919749.901
#
#
# PIDILITIND.NS
# Weights = 1 3304 2495 920 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for PIDILITIND.NS = 0.892
# Success Rate %age for PIDILITIND.NS = 100
# Total Capital for PIDILITIND.NS = 1710.0
#
#
# Aggregate P/L %age = 1.487
# Success Rate %age = 87.00906344410876
# Total Capital = 921459.901
#
#
# PIIND.NS
# Weights = 1 3335 2520 932 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for PIIND.NS = 1.119
# Success Rate %age for PIIND.NS = 83
# Total Capital for PIIND.NS = 14281.9
#
#
# Aggregate P/L %age = 1.481
# Success Rate %age = 86.94362017804154
# Total Capital = 935741.801
#
#
# PNB.NS
# Weights = 1 3366 2544 944 1
# [*********************100%***********************]  1 of 1 completed
# POWERGRID.NS
# Weights = 1 3366 2544 944 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for POWERGRID.NS = 3.204
# Success Rate %age for POWERGRID.NS = 100
# Total Capital for POWERGRID.NS = 440.1
#
#
# Aggregate P/L %age = 1.482
# Success Rate %age = 87.02064896755162
# Total Capital = 936181.901
#
#
# PVR.NS
# Weights = 1 3397 2568 956 1
# [*********************100%***********************]  1 of 1 completed
# RAMCOCEM.NS
# Weights = 1 3397 2568 956 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for RAMCOCEM.NS = 0.296
# Success Rate %age for RAMCOCEM.NS = 50
# Total Capital for RAMCOCEM.NS = 1975.6
#
#
# Aggregate P/L %age = 1.479
# Success Rate %age = 86.80351906158357
# Total Capital = 938157.501
#
#
# RBLBANK.NS
# Weights = 1 3428 2592 968 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for RBLBANK.NS = 4.026
# Success Rate %age for RBLBANK.NS = 100
# Total Capital for RBLBANK.NS = 439.6
#
#
# Aggregate P/L %age = 1.481
# Success Rate %age = 86.88046647230321
# Total Capital = 938597.101
#
#
# RECLTD.NS
# Weights = 1 3459 2616 980 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for RECLTD.NS = 0.26
# Success Rate %age for RECLTD.NS = 50
# Total Capital for RECLTD.NS = 269.4
#
#
# Aggregate P/L %age = 1.48
# Success Rate %age = 86.66666666666667
# Total Capital = 938866.501
#
#
# RELIANCE.NS
# Weights = 1 3490 2639 992 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for RELIANCE.NS = 0.704
# Success Rate %age for RELIANCE.NS = 100
# Total Capital for RELIANCE.NS = 11885.9
#
#
# Aggregate P/L %age = 1.47
# Success Rate %age = 86.8945868945869
# Total Capital = 950752.401
#
#
# SAIL.NS
# Weights = 1 3521 2663 1005 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for SAIL.NS = 12.225
# Success Rate %age for SAIL.NS = 100
# Total Capital for SAIL.NS = 540.7
#
#
# Aggregate P/L %age = 1.477
# Success Rate %age = 87.11484593837535
# Total Capital = 951293.101
#
#
# SBILIFE.NS
# Weights = 1 3552 2687 1018 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for SBILIFE.NS = 0.371
# Success Rate %age for SBILIFE.NS = 75
# Total Capital for SBILIFE.NS = 3703.65
#
#
# Aggregate P/L %age = 1.472
# Success Rate %age = 86.98060941828255
# Total Capital = 954996.751
#
#
# SBIN.NS
# Weights = 1 3583 2711 1031 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for SBIN.NS = 0.732
# Success Rate %age for SBIN.NS = 100
# Total Capital for SBIN.NS = 1468.15
#
#
# Aggregate P/L %age = 1.471
# Success Rate %age = 87.12328767123287
# Total Capital = 956464.901
#
#
# SHREECEM.NS
# Weights = 1 3614 2735 1044 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for SHREECEM.NS = 1.765
# Success Rate %age for SHREECEM.NS = 100
# Total Capital for SHREECEM.NS = 111144.801
#
#
# Aggregate P/L %age = 1.502
# Success Rate %age = 87.26287262872629
# Total Capital = 1067609.702
#
#
# SIEMENS.NS
# Weights = 1 3645 2759 1057 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for SIEMENS.NS = -0.122
# Success Rate %age for SIEMENS.NS = 75
# Total Capital for SIEMENS.NS = 7659.3
#
#
# Aggregate P/L %age = 1.49
# Success Rate %age = 87.1313672922252
# Total Capital = 1075269.002
#
#
# SRF.NS
# Weights = 1 3676 2783 1070 1
# [*********************100%***********************]  1 of 1 completed
# NO TRADES FOR SRF.NS
#
#
# Aggregate P/L %age = 1.49
# Success Rate %age = 87.1313672922252
# Total Capital = 1075269.002
#
#
# SRTRANSFIN.NS
# Weights = 1 3707 2807 1083 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for SRTRANSFIN.NS = 1.46
# Success Rate %age for SRTRANSFIN.NS = 67
# Total Capital for SRTRANSFIN.NS = 8318.0
#
#
# Aggregate P/L %age = 1.49
# Success Rate %age = 86.80738786279683
# Total Capital = 1083587.002
#
#
# SUNPHARMA.NS
# Weights = 1 3738 2831 1095 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for SUNPHARMA.NS = 1.381
# Success Rate %age for SUNPHARMA.NS = 100
# Total Capital for SUNPHARMA.NS = 1245.6
#
#
# Aggregate P/L %age = 1.49
# Success Rate %age = 86.8766404199475
# Total Capital = 1084832.602
#
#
# SUNTV.NS
# Weights = 1 3769 2855 1107 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for SUNTV.NS = 5.56
# Success Rate %age for SUNTV.NS = 100
# Total Capital for SUNTV.NS = 1429.8
#
#
# Aggregate P/L %age = 1.495
# Success Rate %age = 86.97916666666666
# Total Capital = 1086262.402
#
#
# TATACHEM.NS
# Weights = 1 3800 2879 1119 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for TATACHEM.NS = 2.721
# Success Rate %age for TATACHEM.NS = 100
# Total Capital for TATACHEM.NS = 2960.6
#
#
# Aggregate P/L %age = 1.499
# Success Rate %age = 87.11340206185567
# Total Capital = 1089223.002
#
#
# TATACONSUM.NS
# Weights = 1 3832 2903 1131 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for TATACONSUM.NS = 1.67
# Success Rate %age for TATACONSUM.NS = 100
# Total Capital for TATACONSUM.NS = 5125.05
#
#
# Aggregate P/L %age = 1.499
# Success Rate %age = 87.37373737373737
# Total Capital = 1094348.052
#
#
# TATAMOTORS.NS
# Weights = 1 3864 2927 1143 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for TATAMOTORS.NS = 1.698
# Success Rate %age for TATAMOTORS.NS = 60
# Total Capital for TATAMOTORS.NS = 1516.25
#
#
# Aggregate P/L %age = 1.5
# Success Rate %age = 87.03241895261846
# Total Capital = 1095864.302
#
#
# TATAPOWER.NS
# Weights = 1 3896 2951 1154 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for TATAPOWER.NS = 2.458
# Success Rate %age for TATAPOWER.NS = 100
# Total Capital for TATAPOWER.NS = 209.55
#
#
# Aggregate P/L %age = 1.5
# Success Rate %age = 87.09677419354838
# Total Capital = 1096073.852
#
#
# TATASTEEL.NS
# Weights = 1 3928 2975 1166 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for TATASTEEL.NS = 3.359
# Success Rate %age for TATASTEEL.NS = 88
# Total Capital for TATASTEEL.NS = 7158.2
#
#
# Aggregate P/L %age = 1.512
# Success Rate %age = 87.10462287104623
# Total Capital = 1103232.052
#
#
# TCS.NS
# Weights = 1 3961 2999 1178 1
# [*********************100%***********************]  1 of 1 completed
# TECHM.NS
# Weights = 1 3961 2999 1178 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for TECHM.NS = 2.589
# Success Rate %age for TECHM.NS = 100
# Total Capital for TECHM.NS = 2954.5
#
#
# Aggregate P/L %age = 1.515
# Success Rate %age = 87.19806763285024
# Total Capital = 1106186.552
#
#
# TITAN.NS
# Weights = 1 3994 3023 1190 1
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS
# Weights = 1 3994 3023 1190 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for TORNTPHARM.NS = 1.919
# Success Rate %age for TORNTPHARM.NS = 100
# Total Capital for TORNTPHARM.NS = 9963.2
#
#
# Aggregate P/L %age = 1.518
# Success Rate %age = 87.32057416267942
# Total Capital = 1116149.752
#
#
# TORNTPOWER.NS
# Weights = 1 4026 3047 1202 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for TORNTPOWER.NS = 1.106
# Success Rate %age for TORNTPOWER.NS = 100
# Total Capital for TORNTPOWER.NS = 827.2
#
#
# Aggregate P/L %age = 1.518
# Success Rate %age = 87.38095238095238
# Total Capital = 1116976.952
#
#
# TRENT.NS
# Weights = 1 4059 3071 1214 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for TRENT.NS = 1.731
# Success Rate %age for TRENT.NS = 83
# Total Capital for TRENT.NS = 4644.5
#
#
# Aggregate P/L %age = 1.519
# Success Rate %age = 87.32394366197182
# Total Capital = 1121621.452
#
#
# TVSMOTOR.NS
# Weights = 1 4092 3095 1225 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for TVSMOTOR.NS = 1.094
# Success Rate %age for TVSMOTOR.NS = 100
# Total Capital for TVSMOTOR.NS = 1824.1
#
#
# Aggregate P/L %age = 1.518
# Success Rate %age = 87.41258741258741
# Total Capital = 1123445.552
#
#
# UBL.NS
# Weights = 1 4125 3119 1237 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for UBL.NS = 2.025
# Success Rate %age for UBL.NS = 100
# Total Capital for UBL.NS = 4790.65
#
#
# Aggregate P/L %age = 1.52
# Success Rate %age = 87.52886836027713
# Total Capital = 1128236.202
#
#
# ULTRACEMCO.NS
# Weights = 1 4158 3143 1249 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ULTRACEMCO.NS = 0.444
# Success Rate %age for ULTRACEMCO.NS = 100
# Total Capital for ULTRACEMCO.NS = 13118.05
#
#
# Aggregate P/L %age = 1.508
# Success Rate %age = 87.58620689655172
# Total Capital = 1141354.252
#
#
# UPL.NS
# Weights = 1 4191 3167 1261 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for UPL.NS = 7.298
# Success Rate %age for UPL.NS = 100
# Total Capital for UPL.NS = 1997.7
#
#
# Aggregate P/L %age = 1.518
# Success Rate %age = 87.67123287671232
# Total Capital = 1143351.952
#
#
# VEDL.NS
# Weights = 1 4224 3191 1273 1
# [*********************100%***********************]  1 of 1 completed
# VOLTAS.NS
# Weights = 1 4224 3191 1273 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for VOLTAS.NS = 1.57
# Success Rate %age for VOLTAS.NS = 100
# Total Capital for VOLTAS.NS = 5736.85
#
#
# Aggregate P/L %age = 1.518
# Success Rate %age = 87.83783783783784
# Total Capital = 1149088.802
#
#
# WIPRO.NS
# Weights = 1 4257 3215 1285 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for WIPRO.NS = 2.967
# Success Rate %age for WIPRO.NS = 75
# Total Capital for WIPRO.NS = 1745.85
#
#
# Aggregate P/L %age = 1.521
# Success Rate %age = 87.72321428571429
# Total Capital = 1150834.652
#
#
# ZEEL.NS
# Weights = 1 4290 3239 1297 1
# [*********************100%***********************]  1 of 1 completed
# Aggregate P/L %age for ZEEL.NS = 3.371
# Success Rate %age for ZEEL.NS = 100
# Total Capital for ZEEL.NS = 972.9
#
#
# Aggregate P/L %age = 1.522
# Success Rate %age = 87.85871964679912
# Total Capital = 1151807.552
#
#
# ******************After INITIALISATION****************************
# 1,48,70,91,1
# *******************NOW RUNNING WITH UPDATED WEIGHTS*****************************
# AARTIIND.NS
# [*********************100%***********************]  1 of 1 completed
# ACC.NS
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS
# [*********************100%***********************]  1 of 1 completed
# ADANIPORTS.NS
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS
# [*********************100%***********************]  1 of 1 completed
# AMARAJABAT.NS
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS
# [*********************100%***********************]  1 of 1 completed
# APLLTD.NS
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS
# [*********************100%***********************]  1 of 1 completed
# APOLLOTYRE.NS
# [*********************100%***********************]  1 of 1 completed
# ASHOKLEY.NS
# [*********************100%***********************]  1 of 1 completed
# ASIANPAINT.NS
# [*********************100%***********************]  1 of 1 completed
# AUBANK.NS
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS
# [*********************100%***********************]  1 of 1 completed
# AXISBANK.NS
# [*********************100%***********************]  1 of 1 completed
# BAJAJFINSV.NS
# [*********************100%***********************]  1 of 1 completed
# BAJAJ-AUTO.NS
# [*********************100%***********************]  1 of 1 completed
# BAJFINANCE.NS
# [*********************100%***********************]  1 of 1 completed
# BALKRISIND.NS
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS
# [*********************100%***********************]  1 of 1 completed
# BANKBARODA.NS
# [*********************100%***********************]  1 of 1 completed
# ^NSEBANK
# [*********************100%***********************]  1 of 1 completed
# BATAINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# BEL.NS
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS
# [*********************100%***********************]  1 of 1 completed
# BHARATFORG.NS
# [*********************100%***********************]  1 of 1 completed
# BHARTIARTL.NS
# [*********************100%***********************]  1 of 1 completed
# BHEL.NS
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS
# [*********************100%***********************]  1 of 1 completed
# BOSCHLTD.NS
# [*********************100%***********************]  1 of 1 completed
# BPCL.NS
# [*********************100%***********************]  1 of 1 completed
# BRITANNIA.NS
# [*********************100%***********************]  1 of 1 completed
# CADILAHC.NS
# [*********************100%***********************]  1 of 1 completed
# CANBK.NS
# [*********************100%***********************]  1 of 1 completed
# CHOLAFIN.NS
# [*********************100%***********************]  1 of 1 completed
# CIPLA.NS
# [*********************100%***********************]  1 of 1 completed
# COALINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# COFORGE.NS
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS
# [*********************100%***********************]  1 of 1 completed
# CONCOR.NS
# [*********************100%***********************]  1 of 1 completed
# CUB.NS
# [*********************100%***********************]  1 of 1 completed
# CUMMINSIND.NS
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS
# [*********************100%***********************]  1 of 1 completed
# DEEPAKNTR.NS
# [*********************100%***********************]  1 of 1 completed
# DIVISLAB.NS
# [*********************100%***********************]  1 of 1 completed
# DLF.NS
# [*********************100%***********************]  1 of 1 completed
# DRREDDY.NS
# [*********************100%***********************]  1 of 1 completed
# EICHERMOT.NS
# [*********************100%***********************]  1 of 1 completed
# ESCORTS.NS
# [*********************100%***********************]  1 of 1 completed
# EXIDEIND.NS
# [*********************100%***********************]  1 of 1 completed
# FEDERALBNK.NS
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS
# [*********************100%***********************]  1 of 1 completed
# GLENMARK.NS
# [*********************100%***********************]  1 of 1 completed
# GMRINFRA.NS
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS
# [*********************100%***********************]  1 of 1 completed
# GODREJPROP.NS
# [*********************100%***********************]  1 of 1 completed
# GRANULES.NS
# [*********************100%***********************]  1 of 1 completed
# GRASIM.NS
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS
# [*********************100%***********************]  1 of 1 completed
# HCLTECH.NS
# [*********************100%***********************]  1 of 1 completed
# HDFC.NS
# [*********************100%***********************]  1 of 1 completed
# HDFCBANK.NS
# [*********************100%***********************]  1 of 1 completed
# HDFCLIFE.NS
# [*********************100%***********************]  1 of 1 completed
# HEROMOTOCO.NS
# [*********************100%***********************]  1 of 1 completed
# HINDALCO.NS
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS
# [*********************100%***********************]  1 of 1 completed
# HINDUNILVR.NS
# [*********************100%***********************]  1 of 1 completed
# IBULHSGFIN.NS
# [*********************100%***********************]  1 of 1 completed
# ICICIBANK.NS
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS
# [*********************100%***********************]  1 of 1 completed
# IDEA.NS
# [*********************100%***********************]  1 of 1 completed
# IDFCFIRSTB.NS
# [*********************100%***********************]  1 of 1 completed
# IGL.NS
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS
# [*********************100%***********************]  1 of 1 completed
# INDUSINDBK.NS
# [*********************100%***********************]  1 of 1 completed
# INFY.NS
# [*********************100%***********************]  1 of 1 completed
# IOC.NS
# [*********************100%***********************]  1 of 1 completed
# IRCTC.NS
# [*********************100%***********************]  1 of 1 completed
# ITC.NS
# [*********************100%***********************]  1 of 1 completed
# JINDALSTEL.NS
# [*********************100%***********************]  1 of 1 completed
# JSWSTEEL.NS
# [*********************100%***********************]  1 of 1 completed
# JUBLFOOD.NS
# [*********************100%***********************]  1 of 1 completed
# KOTAKBANK.NS
# [*********************100%***********************]  1 of 1 completed
# LICHSGFIN.NS
# [*********************100%***********************]  1 of 1 completed
# LT.NS
# [*********************100%***********************]  1 of 1 completed
# LTI.NS
# [*********************100%***********************]  1 of 1 completed
# LTTS.NS
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS
# [*********************100%***********************]  1 of 1 completed
# MANAPPURAM.NS
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS
# [*********************100%***********************]  1 of 1 completed
# MARUTI.NS
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS
# [*********************100%***********************]  1 of 1 completed
# MGL.NS
# [*********************100%***********************]  1 of 1 completed
# MINDTREE.NS
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS
# [*********************100%***********************]  1 of 1 completed
# MPHASIS.NS
# [*********************100%***********************]  1 of 1 completed
# MRF.NS
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS
# [*********************100%***********************]  1 of 1 completed
# M&M.NS
# [*********************100%***********************]  1 of 1 completed
# M&MFIN.NS
# [*********************100%***********************]  1 of 1 completed
# NATIONALUM.NS
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS
# [*********************100%***********************]  1 of 1 completed
# NAVINFLUOR.NS
# [*********************100%***********************]  1 of 1 completed
# NCC.NS
# [*********************100%***********************]  1 of 1 completed
# NESTLEIND.NS
# [*********************100%***********************]  1 of 1 completed
# ^NSEI
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS
# [*********************100%***********************]  1 of 1 completed
# NTPC.NS
# [*********************100%***********************]  1 of 1 completed
# ONGC.NS
# [*********************100%***********************]  1 of 1 completed
# PAGEIND.NS
# [*********************100%***********************]  1 of 1 completed
# PEL.NS
# [*********************100%***********************]  1 of 1 completed
# PETRONET.NS
# [*********************100%***********************]  1 of 1 completed
# PFIZER.NS
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS
# [*********************100%***********************]  1 of 1 completed
# PIIND.NS
# [*********************100%***********************]  1 of 1 completed
# PNB.NS
# [*********************100%***********************]  1 of 1 completed
# POWERGRID.NS
# [*********************100%***********************]  1 of 1 completed
# PVR.NS
# [*********************100%***********************]  1 of 1 completed
# RAMCOCEM.NS
# [*********************100%***********************]  1 of 1 completed
# RBLBANK.NS
# [*********************100%***********************]  1 of 1 completed
# RECLTD.NS
# [*********************100%***********************]  1 of 1 completed
# RELIANCE.NS
# [*********************100%***********************]  1 of 1 completed
# SAIL.NS
# [*********************100%***********************]  1 of 1 completed

# %%
c=0
for i in all_trans.index:
    if all_trans['Stock: Correct or Not'][i]=='N/A':
        c=c+1
print('N/A %age = '+ str(c/len(all_trans['Stock: Correct or Not'])*100))

# %%
contra_c = len(np.where((all_trans['Stock: Condition']=='CONTRA TREND TRADE')&(all_trans['Stock: Correct or Not']=='YES'))[0])
contra_w = len(np.where((all_trans['Stock: Condition']=='CONTRA TREND TRADE')&(all_trans['Stock: Correct or Not']=='NO'))[0])
reent_c = len(np.where((all_trans['Stock: Condition']=='RE-ENTRY TRADE')&(all_trans['Stock: Correct or Not']=='YES'))[0])
reent_w = len(np.where((all_trans['Stock: Condition']=='RE-ENTRY TRADE')&(all_trans['Stock: Correct or Not']=='NO'))[0])
ddiv_c = len(np.where((all_trans['Stock: Condition']=='DAILY DIVERGENCE TRADE')&(all_trans['Stock: Correct or Not']=='YES'))[0])
ddiv_w = len(np.where((all_trans['Stock: Condition']=='DAILY DIVERGENCE TRADE')&(all_trans['Stock: Correct or Not']=='NO'))[0])
dgap_c = len(np.where((all_trans['Stock: Condition']=='DAILY GAP')&(all_trans['Stock: Correct or Not']=='YES'))[0])
dgap_w = len(np.where((all_trans['Stock: Condition']=='DAILY GAP')&(all_trans['Stock: Correct or Not']=='NO'))[0])
hgap_c = len(np.where((all_trans['Stock: Condition']=='HOURLY GAP')&(all_trans['Stock: Correct or Not']=='YES'))[0])
hgap_w = len(np.where((all_trans['Stock: Condition']=='HOURLY GAP')&(all_trans['Stock: Correct or Not']=='NO'))[0])

#print('%age of Correct Contra Trend Trades = '+ str(contra_c*100/(contra_w+contra_c)))
print('%age of Correct Re-Entry Trades = '+ str(reent_c*100/(reent_w+reent_c)))
print('%age of Correct Daily Divergence Trades = '+ str(ddiv_c*100/(ddiv_w+ddiv_c)))
print('%age of Correct Daily Gap Trades = '+ str(dgap_c*100/(dgap_w+dgap_c)))
#print('%age of Correct Hourly Gap Trades = '+ str(hgap_c*100/(hgap_w+hgap_c)))

# %%
print('Total numerical profit = '+ str(total_pl))
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth', 800)
temp = all_trans[all_trans['Trade: Exit Condition']=='TRAILING STOPLOSS']
temp

# %%
re = 0
dd = 0
ct = 0
for i in all_trans.index:
    if all_trans['Stock: Correct or Not'][i] == 'NO' and all_trans['Stock: Condition'][i] == 'RE-ENTRY TRADE':
        re = re+1
    elif all_trans['Stock: Correct or Not'][i] == 'NO' and all_trans['Stock: Condition'][i] == 'DAILY DIVERGENCE TRADE':
        dd = dd+1
    elif all_trans['Stock: Correct or Not'][i] == 'NO' and all_trans['Stock: Condition'][i] == 'CONTRA-TREND TRADE':
        ct = ct+1
print(re)
print(dd)
print(ct)

# %%
wrong = all_trans[all_trans['Stock: Correct or Not']=='NO']
random_list = wrong.index
em = pd.DataFrame(columns=['Stock: Name','Stock: Correct or Not','Stock: BuD/BeD','Stock: Condition','D1: Date',
                               'D1: Minute','D1: OHLC','D2: Date','D2: Minute','D2: OHLC','Trade: Entry Price',
                              'Trade: Exit Date','Trade: Exit Minute','Trade: Exit Price','Stoploss','Profit/Loss'])

import random
for i in range(6):
    random_num = random.choice(random_list)
    wrong_test = wrong.loc[random_num]
    em = em.append(wrong_test)

em
